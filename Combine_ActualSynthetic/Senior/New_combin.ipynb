# %%
import numpy as np
import pandas as pd
import time
import psutil
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from joblib import dump
import os
from sklearn.multioutput import MultiOutputRegressor

# Load datasets
actual_data = pd.read_csv('original_CMKL1.csv')
synthetic_data_ml = pd.read_csv('synthetic_data_RandomSeaerch_Ensemble.csv')
synthetic_data_gan = pd.read_csv('GANs_synthetic_data.csv')

# Combine synthetic datasets for the ML+GAN case
synthetic_data_combined = pd.concat([synthetic_data_ml, synthetic_data_gan])

# Create directory for saving models
if not os.path.exists('NEW_senior_saved_model'):
    os.makedirs('NEW_senior_saved_model')

# Define models and hyperparameters for grid search
classification_models = {
    'RandomForestClassifier': {
        'model': RandomForestClassifier(random_state=42),
        'params': {
            'n_estimators': [100, 150, 200],
            'max_depth': [10, 15, 20],
            'min_samples_split': [2, 5, 10]
        }
    },
    'LogisticRegression': {
        'model': LogisticRegression(random_state=42, max_iter=1000),
        'params': {
            'C': [0.01, 0.1, 1, 10, 100]
        }
    },
    'DecisionTreeClassifier': {
        'model': DecisionTreeClassifier(random_state=42),
        'params': {
            'max_depth': [10, 15, 20],
            'min_samples_split': [2, 5, 10]
        }
    },
    'GradientBoostingClassifier': {
        'model': GradientBoostingClassifier(random_state=42),
        'params': {
            'n_estimators': [100, 150, 200],
            'learning_rate': [0.01, 0.1, 0.2],
            'max_depth': [3, 5, 7]
        }
    },
    'KNeighborsClassifier': {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [3, 5, 7, 10],
            'weights': ['uniform', 'distance']
        }
    }
}

regression_models = {
    'RandomForestRegressor': {
        'model': MultiOutputRegressor(RandomForestRegressor(random_state=42)),
        'params': {
            'estimator__n_estimators': [100, 150, 200],
            'estimator__max_depth': [10, 15, 20],
            'estimator__min_samples_split': [2, 5, 10]
        }
    },
    'LinearRegression': {
        'model': MultiOutputRegressor(LinearRegression()),
        'params': {
            'estimator__fit_intercept': [True, False]
        }
    },
    'DecisionTreeRegressor': {
        'model': MultiOutputRegressor(DecisionTreeRegressor(random_state=42)),
        'params': {
            'estimator__max_depth': [10, 15, 20],
            'estimator__min_samples_split': [2, 5, 10]
        }
    },
    'GradientBoostingRegressor': {
        'model': MultiOutputRegressor(GradientBoostingRegressor(random_state=42)),
        'params': {
            'estimator__n_estimators': [100, 150, 200],
            'estimator__learning_rate': [0.01, 0.1, 0.2],
            'estimator__max_depth': [3, 5, 7]
        }
    },
    'KNeighborsRegressor': {
        'model': KNeighborsRegressor(),
        'params': {
            'n_neighbors': [3, 5, 7, 10],
            'weights': ['uniform', 'distance']
        }
    }
}

# Function to create combined dataset with given ratio for each floor
def create_combined_dataset(actual_data, synthetic_data, ratio):
    combined_data = pd.DataFrame()
    floors = actual_data['z'].unique()
    for floor in floors:
        actual_floor_data = actual_data[actual_data['z'] == floor]
        synthetic_floor_data = synthetic_data[synthetic_data['z'] == floor]
        
        n_actual = int(len(actual_floor_data) * ratio)
        n_synthetic = len(actual_floor_data) - n_actual
        
        actual_sample = actual_floor_data.sample(n_actual, random_state=42)
        synthetic_sample = synthetic_floor_data.sample(n_synthetic, random_state=42)
        
        combined_floor_data = pd.concat([actual_sample, synthetic_sample])
        combined_data = pd.concat([combined_data, combined_floor_data], ignore_index=True)
        
    return combined_data

# Function to perform grid search and train the model
def train_model_with_grid_search(X_train, y_train, model_config):
    grid_search = GridSearchCV(model_config['model'], model_config['params'], cv=10, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X_train, y_train)
    return grid_search.best_estimator_, -grid_search.best_score_

# Function to calculate Mean Distance Error
def mean_distance_error(y_true, y_pred):
    return np.mean(np.sqrt(np.sum((y_true - y_pred) ** 2, axis=1)))

# Train and evaluate models
ratios = [0.9, 0.8, 0.7, 0.6, 0.5]
datasets = {
    'actual_ml': synthetic_data_ml,
    'actual_gan': synthetic_data_gan,
    'actual_ml_gan': synthetic_data_combined
}
results = {}

for dataset_name, synthetic_data in datasets.items():
    for ratio in ratios:
        combined_data = create_combined_dataset(actual_data, synthetic_data, ratio)
        
        # Floor classification training and evaluation
        X_train, X_test, y_train, y_test = train_test_split(combined_data[[f'RSSI{i+1}' for i in range(18)]], combined_data['z'], test_size=0.3, random_state=42)
        for model_name, model_config in classification_models.items():
            start_time = time.time()
            process = psutil.Process()
            initial_memory = process.memory_info().rss / (1024 ** 2)  # Convert to MB
            
            best_model, best_score = train_model_with_grid_search(X_train, y_train, model_config)
            
            training_time = time.time() - start_time
            training_memory = (process.memory_info().rss / (1024 ** 2)) - initial_memory
            
            start_time = time.time()
            initial_memory = process.memory_info().rss / (1024 ** 2)
            y_pred = best_model.predict(X_test)
            
            prediction_time = time.time() - start_time
            prediction_memory = (process.memory_info().rss / (1024 ** 2)) - initial_memory
            
            mae = mean_absolute_error(y_test, y_pred)
            
            results[f'{dataset_name}_{ratio}_{model_name}_floor'] = {
                'Mean Absolute Error': mae,
                'Training Time (s)': training_time,
                'Prediction Time (s)': prediction_time,
                'Memory Usage During Training (MB)': training_memory,
                'Memory Usage During Prediction (MB)': prediction_memory
            }
            dump(best_model, f'NEW_senior_saved_model/{dataset_name}_{ratio}_{model_name}_floor.joblib')
        
        # Coordinate regression training and evaluation
        X_train, X_test, y_train, y_test = train_test_split(combined_data[[f'RSSI{i+1}' for i in range(18)]], combined_data[['x', 'y']], test_size=0.3, random_state=42)
        for model_name, model_config in regression_models.items():
            start_time = time.time()
            process = psutil.Process()
            initial_memory = process.memory_info().rss / (1024 ** 2)  # Convert to MB
            
            best_model, best_score = train_model_with_grid_search(X_train, y_train, model_config)
            
            training_time = time.time() - start_time
            training_memory = (process.memory_info().rss / (1024 ** 2)) - initial_memory
            
            start_time = time.time()
            initial_memory = process.memory_info().rss / (1024 ** 2)
            y_pred = best_model.predict(X_test)
            
            prediction_time = time.time() - start_time
            prediction_memory = (process.memory_info().rss / (1024 ** 2)) - initial_memory
            
            mde = mean_distance_error(y_test, y_pred)
            
            results[f'{dataset_name}_{ratio}_{model_name}_coord'] = {
                'Mean Distance Error (meters)': mde,
                'Training Time (s)': training_time,
                'Prediction Time (s)': prediction_time,
                'Memory Usage During Training (MB)': training_memory,
                'Memory Usage During Prediction (MB)': prediction_memory
            }
            dump(best_model, f'NEW_senior_saved_model/{dataset_name}_{ratio}_{model_name}_coord.joblib')

# Print results
for key, metrics in results.items():
    print(f'Results for {key}:')
    for metric_name, value in metrics.items():
        print(f'  {metric_name}: {value}')
# Out:
# Results for actual_ml_0.9_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 3.494168519973755
#   Prediction Time (s): 0.0050525665283203125
#   Memory Usage During Training (MB): 1.61328125
#   Memory Usage During Prediction (MB): 0.02734375
# Results for actual_ml_0.9_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.07499814033508301
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.3515625
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.9_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.003401360544217687
#   Training Time (s): 0.06589460372924805
#   Prediction Time (s): 0.00099945068359375
#   Memory Usage During Training (MB): 0.0078125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.9_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 5.032672166824341
#   Prediction Time (s): 0.002953052520751953
#   Memory Usage During Training (MB): 0.4375
#   Memory Usage During Prediction (MB): 0.05859375
# Results for actual_ml_0.9_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.25089216232299805
#   Prediction Time (s): 1.0042381286621094
#   Memory Usage During Training (MB): 0.0078125
#   Memory Usage During Prediction (MB): -0.0625
# Results for actual_ml_0.9_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0982296536429785
#   Training Time (s): 18.10137629508972
#   Prediction Time (s): 0.025007247924804688
#   Memory Usage During Training (MB): 20.32421875
#   Memory Usage During Prediction (MB): 0.109375
# Results for actual_ml_0.9_LinearRegression_coord:
#   Mean Distance Error (meters): 4.201668013551345
#   Training Time (s): 0.031323909759521484
#   Prediction Time (s): 0.0019843578338623047
#   Memory Usage During Training (MB): -20.53125
#   Memory Usage During Prediction (MB): -0.0546875
# Results for actual_ml_0.9_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.1392596045440444
#   Training Time (s): 0.11686205863952637
#   Prediction Time (s): 0.0008087158203125
#   Memory Usage During Training (MB): 2.125
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.9_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.0685319867557719
#   Training Time (s): 13.34060788154602
#   Prediction Time (s): 0.010728836059570312
#   Memory Usage During Training (MB): 1.98046875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.9_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.0187463303232713
#   Training Time (s): 0.05823922157287598
#   Prediction Time (s): 0.09479522705078125
#   Memory Usage During Training (MB): -7.140625
#   Memory Usage During Prediction (MB): 1.1171875
# Results for actual_ml_0.8_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 1.7305164337158203
#   Prediction Time (s): 0.003988504409790039
#   Memory Usage During Training (MB): 2.3203125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_0.8_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.08509397506713867
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): -0.35546875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.8_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.06581711769104004
#   Prediction Time (s): 0.0009949207305908203
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.8_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 6.323125123977661
#   Prediction Time (s): 0.00160980224609375
#   Memory Usage During Training (MB): 0.25390625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_0.8_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06705617904663086
#   Prediction Time (s): 0.11192512512207031
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -2.5859375
# Results for actual_ml_0.8_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0694083095338178
#   Training Time (s): 24.933658123016357
#   Prediction Time (s): 0.048451900482177734
#   Memory Usage During Training (MB): 51.40625
#   Memory Usage During Prediction (MB): 0.0078125
# Results for actual_ml_0.8_LinearRegression_coord:
#   Mean Distance Error (meters): 4.060952336145102
#   Training Time (s): 0.03539109230041504
#   Prediction Time (s): 0.001538991928100586
#   Memory Usage During Training (MB): -52.5625
#   Memory Usage During Prediction (MB): 0.046875
# Results for actual_ml_0.8_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.1284897346284652
#   Training Time (s): 0.13752102851867676
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 2.31640625
#   Memory Usage During Prediction (MB): 0.015625
# Results for actual_ml_0.8_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.0520929692335361
#   Training Time (s): 17.46381402015686
#   Prediction Time (s): 0.010590791702270508
#   Memory Usage During Training (MB): 1.296875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.8_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9649210755556662
#   Training Time (s): 0.0989217758178711
#   Prediction Time (s): 0.08605241775512695
#   Memory Usage During Training (MB): -4.0859375
#   Memory Usage During Prediction (MB): 1.31640625
# Results for actual_ml_0.7_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.04130482673645
#   Prediction Time (s): 0.007014274597167969
#   Memory Usage During Training (MB): 1.95703125
#   Memory Usage During Prediction (MB): 0.11328125
# Results for actual_ml_0.7_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06863212585449219
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): -0.359375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.7_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.07813119888305664
#   Prediction Time (s): 0.0006232261657714844
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.7_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 7.710793972015381
#   Prediction Time (s): 0.0019989013671875
#   Memory Usage During Training (MB): 0.32421875
#   Memory Usage During Prediction (MB): 0.09375
# Results for actual_ml_0.7_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.0678248405456543
#   Prediction Time (s): 0.09572935104370117
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -0.74609375
# Results for actual_ml_0.7_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0569585940153772
#   Training Time (s): 30.947279930114746
#   Prediction Time (s): 0.051644325256347656
#   Memory Usage During Training (MB): 60.0390625
#   Memory Usage During Prediction (MB): 0.0078125
# Results for actual_ml_0.7_LinearRegression_coord:
#   Mean Distance Error (meters): 3.8892414802503743
#   Training Time (s): 0.03371000289916992
#   Prediction Time (s): 0.002582073211669922
#   Memory Usage During Training (MB): -63.9609375
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.7_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.4156982439147552
#   Training Time (s): 0.16836786270141602
#   Prediction Time (s): 0.0020055770874023438
#   Memory Usage During Training (MB): 2.83984375
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_ml_0.7_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.0413887425975041
#   Training Time (s): 21.88450837135315
#   Prediction Time (s): 0.010940790176391602
#   Memory Usage During Training (MB): 1.93359375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.7_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9973397947415521
#   Training Time (s): 0.06766748428344727
#   Prediction Time (s): 0.09744882583618164
#   Memory Usage During Training (MB): -4.06640625
#   Memory Usage During Prediction (MB): 1.73828125
# Results for actual_ml_0.6_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.1581437587738037
#   Prediction Time (s): 0.006928443908691406
#   Memory Usage During Training (MB): 2.109375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.6_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.07075238227844238
#   Prediction Time (s): 0.0009288787841796875
#   Memory Usage During Training (MB): -0.359375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.6_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.08041977882385254
#   Prediction Time (s): 0.001003265380859375
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.6_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 8.846073389053345
#   Prediction Time (s): 0.002007007598876953
#   Memory Usage During Training (MB): 0.203125
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_ml_0.6_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.0680842399597168
#   Prediction Time (s): 0.1043558120727539
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.015625
# Results for actual_ml_0.6_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0089337645687924
#   Training Time (s): 34.89895009994507
#   Prediction Time (s): 0.04077935218811035
#   Memory Usage During Training (MB): 51.3046875
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.6_LinearRegression_coord:
#   Mean Distance Error (meters): 3.724108318809784
#   Training Time (s): 0.03538846969604492
#   Prediction Time (s): 0.0019855499267578125
#   Memory Usage During Training (MB): -53.0234375
#   Memory Usage During Prediction (MB): 0.0234375
# Results for actual_ml_0.6_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.3667756120078451
#   Training Time (s): 0.17927980422973633
#   Prediction Time (s): 0.0009582042694091797
#   Memory Usage During Training (MB): 2.10546875
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.6_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.9530585031757876
#   Training Time (s): 25.049168825149536
#   Prediction Time (s): 0.008079767227172852
#   Memory Usage During Training (MB): 0.75390625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.6_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9589072668977406
#   Training Time (s): 0.05751490592956543
#   Prediction Time (s): 0.09551644325256348
#   Memory Usage During Training (MB): 2.1015625
#   Memory Usage During Prediction (MB): -1.00390625
# Results for actual_ml_0.5_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.16426420211792
#   Prediction Time (s): 0.003023862838745117
#   Memory Usage During Training (MB): -9.609375
#   Memory Usage During Prediction (MB): 0.13671875
# Results for actual_ml_0.5_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06856775283813477
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 1.51953125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.5_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.08022308349609375
#   Prediction Time (s): 0.001018524169921875
#   Memory Usage During Training (MB): 0.26953125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.5_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 10.228013277053833
#   Prediction Time (s): 0.002009153366088867
#   Memory Usage During Training (MB): 0.30078125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.5_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06880521774291992
#   Prediction Time (s): 0.10187649726867676
#   Memory Usage During Training (MB): 0.01953125
#   Memory Usage During Prediction (MB): 0.4765625
# Results for actual_ml_0.5_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.9486096950029775
#   Training Time (s): 42.99396204948425
#   Prediction Time (s): 0.05470561981201172
#   Memory Usage During Training (MB): 74.18359375
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.5_LinearRegression_coord:
#   Mean Distance Error (meters): 3.5223383320196096
#   Training Time (s): 0.10193395614624023
#   Prediction Time (s): 0.0020067691802978516
#   Memory Usage During Training (MB): -76.96484375
#   Memory Usage During Prediction (MB): 0.0234375
# Results for actual_ml_0.5_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.1088143542026667
#   Training Time (s): 0.22293806076049805
#   Prediction Time (s): 0.0011010169982910156
#   Memory Usage During Training (MB): 2.140625
#   Memory Usage During Prediction (MB): 0.046875
# Results for actual_ml_0.5_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.985092848960107
#   Training Time (s): 31.53988027572632
#   Prediction Time (s): 0.01110076904296875
#   Memory Usage During Training (MB): 1.7890625
#   Memory Usage During Prediction (MB): 0.078125
# Results for actual_ml_0.5_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9208155300431539
#   Training Time (s): 0.18143510818481445
#   Prediction Time (s): 0.09588193893432617
#   Memory Usage During Training (MB): -4.0234375
#   Memory Usage During Prediction (MB): 1.6015625
# Results for actual_gan_0.9_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 1.7173171043395996
#   Prediction Time (s): 0.006598234176635742
#   Memory Usage During Training (MB): 2.1640625
#   Memory Usage During Prediction (MB): 0.125
# Results for actual_gan_0.9_LogisticRegression_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 0.08742427825927734
#   Prediction Time (s): 0.000978708267211914
#   Memory Usage During Training (MB): -0.34375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.9_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.005442176870748299
#   Training Time (s): 0.06449675559997559
#   Prediction Time (s): 0.0009119510650634766
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.9_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 5.045174837112427
#   Prediction Time (s): 0.0019690990447998047
#   Memory Usage During Training (MB): 0.6328125
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_gan_0.9_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.07018256187438965
#   Prediction Time (s): 0.08307147026062012
#   Memory Usage During Training (MB): 0.03515625
#   Memory Usage During Prediction (MB): -1.66796875
# Results for actual_gan_0.9_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.3206416307956308
#   Training Time (s): 19.210143089294434
#   Prediction Time (s): 0.025777339935302734
#   Memory Usage During Training (MB): 19.9296875
#   Memory Usage During Prediction (MB): 0.078125
# Results for actual_gan_0.9_LinearRegression_coord:
#   Mean Distance Error (meters): 4.326793135810211
#   Training Time (s): 0.029533863067626953
#   Prediction Time (s): 0.0009989738464355469
#   Memory Usage During Training (MB): -23.7109375
#   Memory Usage During Prediction (MB): 0.0078125
# Results for actual_gan_0.9_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.4455443890077089
#   Training Time (s): 0.12264323234558105
#   Prediction Time (s): 0.0010154247283935547
#   Memory Usage During Training (MB): 2.84375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.9_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.2663842818431619
#   Training Time (s): 13.487234830856323
#   Prediction Time (s): 0.010999679565429688
#   Memory Usage During Training (MB): 1.35546875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.9_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.245913337752236
#   Training Time (s): 0.058840274810791016
#   Prediction Time (s): 0.09224700927734375
#   Memory Usage During Training (MB): -4.140625
#   Memory Usage During Prediction (MB): -1.86328125
# Results for actual_gan_0.8_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 2.0233964920043945
#   Prediction Time (s): 0.006999015808105469
#   Memory Usage During Training (MB): 0.2109375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.8_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.09411787986755371
#   Prediction Time (s): 0.0010063648223876953
#   Memory Usage During Training (MB): -0.359375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.8_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.07912325859069824
#   Prediction Time (s): 0.001001119613647461
#   Memory Usage During Training (MB): -5.44921875
#   Memory Usage During Prediction (MB): 0.03125
# Results for actual_gan_0.8_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 7.524878740310669
#   Prediction Time (s): 0.0030012130737304688
#   Memory Usage During Training (MB): 0.91015625
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_gan_0.8_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 0.06977677345275879
#   Prediction Time (s): 0.09910178184509277
#   Memory Usage During Training (MB): 0.5078125
#   Memory Usage During Prediction (MB): -0.92578125
# Results for actual_gan_0.8_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.4269519163159294
#   Training Time (s): 26.200124740600586
#   Prediction Time (s): 0.051070451736450195
#   Memory Usage During Training (MB): 53.45703125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.8_LinearRegression_coord:
#   Mean Distance Error (meters): 4.390244441224013
#   Training Time (s): 0.033032894134521484
#   Prediction Time (s): 0.001528024673461914
#   Memory Usage During Training (MB): -56.30078125
#   Memory Usage During Prediction (MB): 0.02734375
# Results for actual_gan_0.8_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.7893583600264673
#   Training Time (s): 0.13708710670471191
#   Prediction Time (s): 0.0010447502136230469
#   Memory Usage During Training (MB): 2.1640625
#   Memory Usage During Prediction (MB): 0.04296875
# Results for actual_gan_0.8_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.3043314394646317
#   Training Time (s): 17.743839025497437
#   Prediction Time (s): 0.009668350219726562
#   Memory Usage During Training (MB): 1.55078125
#   Memory Usage During Prediction (MB): 0.04296875
# Results for actual_gan_0.8_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.3653830147607282
#   Training Time (s): 0.17627429962158203
#   Prediction Time (s): 0.0689079761505127
#   Memory Usage During Training (MB): -4.03125
#   Memory Usage During Prediction (MB): 0.14453125
# Results for actual_gan_0.7_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 2.0558691024780273
#   Prediction Time (s): 0.0050008296966552734
#   Memory Usage During Training (MB): -8.45703125
#   Memory Usage During Prediction (MB): 0.13671875
# Results for actual_gan_0.7_LogisticRegression_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 0.0944523811340332
#   Prediction Time (s): 0.0008122920989990234
#   Memory Usage During Training (MB): 2.5625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.7_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.005442176870748299
#   Training Time (s): 0.07960796356201172
#   Prediction Time (s): 0.000993967056274414
#   Memory Usage During Training (MB): 0.25390625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.7_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 8.527483940124512
#   Prediction Time (s): 0.0020096302032470703
#   Memory Usage During Training (MB): 0.69140625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.7_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.06720566749572754
#   Prediction Time (s): 0.09576916694641113
#   Memory Usage During Training (MB): 0.015625
#   Memory Usage During Prediction (MB): -0.046875
# Results for actual_gan_0.7_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.6216269015750062
#   Training Time (s): 30.457317352294922
#   Prediction Time (s): 0.03991270065307617
#   Memory Usage During Training (MB): 52.5703125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.7_LinearRegression_coord:
#   Mean Distance Error (meters): 4.337670569494083
#   Training Time (s): 0.03514218330383301
#   Prediction Time (s): 0.002019643783569336
#   Memory Usage During Training (MB): -56.5390625
#   Memory Usage During Prediction (MB): 0.01953125
# Results for actual_gan_0.7_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.239301165566179
#   Training Time (s): 0.1629953384399414
#   Prediction Time (s): 0.0020012855529785156
#   Memory Usage During Training (MB): 2.7421875
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_gan_0.7_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.6164156650722603
#   Training Time (s): 21.80114197731018
#   Prediction Time (s): 0.010654449462890625
#   Memory Usage During Training (MB): 1.8359375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.7_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.5881793233994046
#   Training Time (s): 0.06746077537536621
#   Prediction Time (s): 0.09634995460510254
#   Memory Usage During Training (MB): -4.234375
#   Memory Usage During Prediction (MB): 1.24609375
# Results for actual_gan_0.6_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.5147664546966553
#   Prediction Time (s): 0.00902700424194336
#   Memory Usage During Training (MB): 0.61328125
#   Memory Usage During Prediction (MB): 0.125
# Results for actual_gan_0.6_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.11117076873779297
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): -0.3359375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.6_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.08669757843017578
#   Prediction Time (s): 0.0009775161743164062
#   Memory Usage During Training (MB): -8.4296875
#   Memory Usage During Prediction (MB): 0.0390625
# Results for actual_gan_0.6_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 10.199228048324585
#   Prediction Time (s): 0.0021233558654785156
#   Memory Usage During Training (MB): 0.51953125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.6_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.09140300750732422
#   Prediction Time (s): 0.07103252410888672
#   Memory Usage During Training (MB): 0.1640625
#   Memory Usage During Prediction (MB): -0.66015625
# Results for actual_gan_0.6_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.7179533988236744
#   Training Time (s): 33.930882930755615
#   Prediction Time (s): 0.027604341506958008
#   Memory Usage During Training (MB): 35.85546875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.6_LinearRegression_coord:
#   Mean Distance Error (meters): 4.224930309074885
#   Training Time (s): 0.03432655334472656
#   Prediction Time (s): 0.002984762191772461
#   Memory Usage During Training (MB): -39.34375
#   Memory Usage During Prediction (MB): 0.015625
# Results for actual_gan_0.6_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.2821335322501635
#   Training Time (s): 0.1772146224975586
#   Prediction Time (s): 0.001049041748046875
#   Memory Usage During Training (MB): 2.77734375
#   Memory Usage During Prediction (MB): 0.015625
# Results for actual_gan_0.6_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.7048820956859494
#   Training Time (s): 26.04561185836792
#   Prediction Time (s): 0.010985374450683594
#   Memory Usage During Training (MB): 2.01953125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.6_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.7534128743555861
#   Training Time (s): 0.058045148849487305
#   Prediction Time (s): 0.0943145751953125
#   Memory Usage During Training (MB): -4.2265625
#   Memory Usage During Prediction (MB): 1.32421875
# Results for actual_gan_0.5_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 2.7299342155456543
#   Prediction Time (s): 0.0069887638092041016
#   Memory Usage During Training (MB): 0.80859375
#   Memory Usage During Prediction (MB): 0.04296875
# Results for actual_gan_0.5_LogisticRegression_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.10151529312133789
#   Prediction Time (s): 0.00099945068359375
#   Memory Usage During Training (MB): -0.359375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.5_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.004081632653061225
#   Training Time (s): 0.08327770233154297
#   Prediction Time (s): 0.001065969467163086
#   Memory Usage During Training (MB): -6.45703125
#   Memory Usage During Prediction (MB): 0.11328125
# Results for actual_gan_0.5_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 10.775267124176025
#   Prediction Time (s): 0.0020036697387695312
#   Memory Usage During Training (MB): 0.62890625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.5_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.06769156455993652
#   Prediction Time (s): 0.09683370590209961
#   Memory Usage During Training (MB): 0.4921875
#   Memory Usage During Prediction (MB): -0.30859375
# Results for actual_gan_0.5_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.9060912258974911
#   Training Time (s): 41.601346015930176
#   Prediction Time (s): 0.05631208419799805
#   Memory Usage During Training (MB): 78.84375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.5_LinearRegression_coord:
#   Mean Distance Error (meters): 4.2496597950573936
#   Training Time (s): 0.0316164493560791
#   Prediction Time (s): 0.0019991397857666016
#   Memory Usage During Training (MB): -83.515625
#   Memory Usage During Prediction (MB): -0.01171875
# Results for actual_gan_0.5_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.423870022632866
#   Training Time (s): 0.19523310661315918
#   Prediction Time (s): 0.0010907649993896484
#   Memory Usage During Training (MB): 2.890625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.5_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.8678431838404081
#   Training Time (s): 29.910268783569336
#   Prediction Time (s): 0.012003660202026367
#   Memory Usage During Training (MB): 2.12890625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.5_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.909717611277868
#   Training Time (s): 0.06902718544006348
#   Prediction Time (s): 0.1463632583618164
#   Memory Usage During Training (MB): -4.03515625
#   Memory Usage During Prediction (MB): 1.14453125
# Results for actual_ml_gan_0.9_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 1.6463441848754883
#   Prediction Time (s): 0.003871440887451172
#   Memory Usage During Training (MB): 2.32421875
#   Memory Usage During Prediction (MB): 0.11328125
# Results for actual_ml_gan_0.9_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.0730440616607666
#   Prediction Time (s): 0.0009119510650634766
#   Memory Usage During Training (MB): -0.35546875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.9_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.003401360544217687
#   Training Time (s): 0.06669497489929199
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.015625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.9_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 5.1664042472839355
#   Prediction Time (s): 0.0019986629486083984
#   Memory Usage During Training (MB): 0.12890625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.9_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.07876300811767578
#   Prediction Time (s): 0.12389326095581055
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -1.49609375
# Results for actual_ml_gan_0.9_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.1065051644498411
#   Training Time (s): 19.338252305984497
#   Prediction Time (s): 0.02484750747680664
#   Memory Usage During Training (MB): 19.1953125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.9_LinearRegression_coord:
#   Mean Distance Error (meters): 4.208108477759677
#   Training Time (s): 0.030792713165283203
#   Prediction Time (s): 0.0020155906677246094
#   Memory Usage During Training (MB): -23.96875
#   Memory Usage During Prediction (MB): 0.0078125
# Results for actual_ml_gan_0.9_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.2148545466276628
#   Training Time (s): 0.11606264114379883
#   Prediction Time (s): 0.0010039806365966797
#   Memory Usage During Training (MB): 2.5703125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.9_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.0735257458632455
#   Training Time (s): 14.090511560440063
#   Prediction Time (s): 0.010946989059448242
#   Memory Usage During Training (MB): 2.25
#   Memory Usage During Prediction (MB): 0.27734375
# Results for actual_ml_gan_0.9_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.0337801891890703
#   Training Time (s): 0.06833314895629883
#   Prediction Time (s): 0.10253143310546875
#   Memory Usage During Training (MB): -4.0078125
#   Memory Usage During Prediction (MB): 1.9140625
# Results for actual_ml_gan_0.8_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 1.8679132461547852
#   Prediction Time (s): 0.00600123405456543
#   Memory Usage During Training (MB): -11.421875
#   Memory Usage During Prediction (MB): 0.12890625
# Results for actual_ml_gan_0.8_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.0834958553314209
#   Prediction Time (s): 0.0009996891021728516
#   Memory Usage During Training (MB): 2.57421875
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_gan_0.8_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.06792879104614258
#   Prediction Time (s): 0.00020432472229003906
#   Memory Usage During Training (MB): 0.26171875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.8_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 6.722592115402222
#   Prediction Time (s): 0.0020666122436523438
#   Memory Usage During Training (MB): 0.7421875
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_ml_gan_0.8_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06752300262451172
#   Prediction Time (s): 0.10572385787963867
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -1.44140625
# Results for actual_ml_gan_0.8_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.092846905331568
#   Training Time (s): 26.64094090461731
#   Prediction Time (s): 0.04938936233520508
#   Memory Usage During Training (MB): 49.53125
#   Memory Usage During Prediction (MB): 0.04296875
# Results for actual_ml_gan_0.8_LinearRegression_coord:
#   Mean Distance Error (meters): 4.079631054835054
#   Training Time (s): 0.03234744071960449
#   Prediction Time (s): 0.0009992122650146484
#   Memory Usage During Training (MB): -53.5546875
#   Memory Usage During Prediction (MB): 0.015625
# Results for actual_ml_gan_0.8_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.2442709471321374
#   Training Time (s): 0.14519715309143066
#   Prediction Time (s): 0.002000570297241211
#   Memory Usage During Training (MB): 2.953125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.8_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.0573073056429791
#   Training Time (s): 18.229606866836548
#   Prediction Time (s): 0.01137685775756836
#   Memory Usage During Training (MB): 1.9140625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.8_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.0214518412554419
#   Training Time (s): 0.06911921501159668
#   Prediction Time (s): 0.08104157447814941
#   Memory Usage During Training (MB): -3.8515625
#   Memory Usage During Prediction (MB): 1.5078125
# Results for actual_ml_gan_0.7_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.03206205368042
#   Prediction Time (s): 0.006036996841430664
#   Memory Usage During Training (MB): -10.859375
#   Memory Usage During Prediction (MB): 0.1328125
# Results for actual_ml_gan_0.7_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06640458106994629
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 2.5546875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.7_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.06872367858886719
#   Prediction Time (s): 0.0009572505950927734
#   Memory Usage During Training (MB): 0.75
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.7_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 8.134117126464844
#   Prediction Time (s): 0.0020008087158203125
#   Memory Usage During Training (MB): 0.265625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.7_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06712460517883301
#   Prediction Time (s): 0.10321640968322754
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -0.95703125
# Results for actual_ml_gan_0.7_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.065426135636494
#   Training Time (s): 32.21203327178955
#   Prediction Time (s): 0.05068850517272949
#   Memory Usage During Training (MB): 64.0546875
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_gan_0.7_LinearRegression_coord:
#   Mean Distance Error (meters): 3.9060976333204325
#   Training Time (s): 0.03332638740539551
#   Prediction Time (s): 0.003022432327270508
#   Memory Usage During Training (MB): -68.9453125
#   Memory Usage During Prediction (MB): 0.015625
# Results for actual_ml_gan_0.7_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.410651276317965
#   Training Time (s): 0.1576557159423828
#   Prediction Time (s): 0.0009827613830566406
#   Memory Usage During Training (MB): 2.921875
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.7_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.032533681426745
#   Training Time (s): 22.022262573242188
#   Prediction Time (s): 0.011056661605834961
#   Memory Usage During Training (MB): 2.1171875
#   Memory Usage During Prediction (MB): 0.20703125
# Results for actual_ml_gan_0.7_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.0050925656729495
#   Training Time (s): 0.057822227478027344
#   Prediction Time (s): 0.0960540771484375
#   Memory Usage During Training (MB): -4.13671875
#   Memory Usage During Prediction (MB): 1.8203125
# Results for actual_ml_gan_0.6_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.2211010456085205
#   Prediction Time (s): 0.007052421569824219
#   Memory Usage During Training (MB): 0.58203125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.6_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.08860349655151367
#   Prediction Time (s): 0.0010905265808105469
#   Memory Usage During Training (MB): -0.359375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.6_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.07998347282409668
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): -8.828125
#   Memory Usage During Prediction (MB): 0.11328125
# Results for actual_ml_gan_0.6_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 8.956363439559937
#   Prediction Time (s): 0.0020096302032470703
#   Memory Usage During Training (MB): 0.6015625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.6_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06798386573791504
#   Prediction Time (s): 0.0948636531829834
#   Memory Usage During Training (MB): 0.46484375
#   Memory Usage During Prediction (MB): -0.7890625
# Results for actual_ml_gan_0.6_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0382288498605727
#   Training Time (s): 37.747910022735596
#   Prediction Time (s): 0.05045676231384277
#   Memory Usage During Training (MB): 71.265625
#   Memory Usage During Prediction (MB): 0.0234375
# Results for actual_ml_gan_0.6_LinearRegression_coord:
#   Mean Distance Error (meters): 3.7490219600602814
#   Training Time (s): 0.03439068794250488
#   Prediction Time (s): 0.002059459686279297
#   Memory Usage During Training (MB): -74.40234375
#   Memory Usage During Prediction (MB): 0.015625
# Results for actual_ml_gan_0.6_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.402305077410718
#   Training Time (s): 0.1857302188873291
#   Prediction Time (s): 0.0009975433349609375
#   Memory Usage During Training (MB): 2.73046875
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.6_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.0295623866981967
#   Training Time (s): 26.195492029190063
#   Prediction Time (s): 0.01100611686706543
#   Memory Usage During Training (MB): 2.08203125
#   Memory Usage During Prediction (MB): 0.20703125
# Results for actual_ml_gan_0.6_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9745267814322653
#   Training Time (s): 0.0676422119140625
#   Prediction Time (s): 0.09157061576843262
#   Memory Usage During Training (MB): -3.8203125
#   Memory Usage During Prediction (MB): 7.6328125
# Results for actual_ml_gan_0.5_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.210402250289917
#   Prediction Time (s): 0.004007577896118164
#   Memory Usage During Training (MB): 0.07421875
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.5_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.08782696723937988
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): -0.33984375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.5_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.08150720596313477
#   Prediction Time (s): 0.0010066032409667969
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.5_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 10.58736538887024
#   Prediction Time (s): 0.002719879150390625
#   Memory Usage During Training (MB): 0.06640625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.5_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06827449798583984
#   Prediction Time (s): 0.09780263900756836
#   Memory Usage During Training (MB): 0.0078125
#   Memory Usage During Prediction (MB): 1.09765625
# Results for actual_ml_gan_0.5_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.986130357885192
#   Training Time (s): 39.853389263153076
#   Prediction Time (s): 0.038836002349853516
#   Memory Usage During Training (MB): 45.44921875
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_gan_0.5_LinearRegression_coord:
#   Mean Distance Error (meters): 3.5521174535728792
#   Training Time (s): 0.032262325286865234
#   Prediction Time (s): 0.0019085407257080078
#   Memory Usage During Training (MB): -60.58984375
#   Memory Usage During Prediction (MB): 0.015625
# Results for actual_ml_gan_0.5_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.4509011172169475
#   Training Time (s): 0.1988368034362793
#   Prediction Time (s): 0.000993490219116211
#   Memory Usage During Training (MB): 2.84375
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_gan_0.5_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.119657002337803
#   Training Time (s): 29.104647874832153
#   Prediction Time (s): 0.006999969482421875
#   Memory Usage During Training (MB): 0.71875
#   Memory Usage During Prediction (MB): 0.20703125
# Results for actual_ml_gan_0.5_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9316424259409888
#   Training Time (s): 0.056261539459228516
#   Prediction Time (s): 0.08894634246826172
#   Memory Usage During Training (MB): 0.49609375
#   Memory Usage During Prediction (MB): -4.16796875

# %%
import numpy as np
import pandas as pd
import time
import psutil
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from joblib import dump, load
import os
from sklearn.multioutput import MultiOutputRegressor

# Load datasets
actual_data = pd.read_csv('original_CMKL1.csv')
synthetic_data_ml = pd.read_csv('synthetic_data_RandomSeaerch_Ensemble.csv')
synthetic_data_gan = pd.read_csv('GANs_synthetic_data.csv')

# Combine synthetic datasets for the ML+GAN case
synthetic_data_combined = pd.concat([synthetic_data_ml, synthetic_data_gan])

# Create directory for saving models
if not os.path.exists('NEW_senior_saved_model'):
    os.makedirs('NEW_senior_saved_model')

# Define models and hyperparameters for grid search
classification_models = {
    'RandomForestClassifier': {
        'model': RandomForestClassifier(random_state=42),
        'params': {
            'n_estimators': [100, 150, 200],
            'max_depth': [10, 15, 20],
            'min_samples_split': [2, 5, 10]
        }
    },
    'LogisticRegression': {
        'model': LogisticRegression(random_state=42, max_iter=1000),
        'params': {
            'C': [0.01, 0.1, 1, 10, 100]
        }
    },
    'DecisionTreeClassifier': {
        'model': DecisionTreeClassifier(random_state=42),
        'params': {
            'max_depth': [10, 15, 20],
            'min_samples_split': [2, 5, 10]
        }
    },
    'GradientBoostingClassifier': {
        'model': GradientBoostingClassifier(random_state=42),
        'params': {
            'n_estimators': [100, 150, 200],
            'learning_rate': [0.01, 0.1, 0.2],
            'max_depth': [3, 5, 7]
        }
    },
    'KNeighborsClassifier': {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [3, 5, 7, 10],
            'weights': ['uniform', 'distance']
        }
    }
}

regression_models = {
    'RandomForestRegressor': {
        'model': MultiOutputRegressor(RandomForestRegressor(random_state=42)),
        'params': {
            'estimator__n_estimators': [100, 150, 200],
            'estimator__max_depth': [10, 15, 20],
            'estimator__min_samples_split': [2, 5, 10]
        }
    },
    'LinearRegression': {
        'model': MultiOutputRegressor(LinearRegression()),
        'params': {
            'estimator__fit_intercept': [True, False]
        }
    },
    'DecisionTreeRegressor': {
        'model': MultiOutputRegressor(DecisionTreeRegressor(random_state=42)),
        'params': {
            'estimator__max_depth': [10, 15, 20],
            'estimator__min_samples_split': [2, 5, 10]
        }
    },
    'GradientBoostingRegressor': {
        'model': MultiOutputRegressor(GradientBoostingRegressor(random_state=42)),
        'params': {
            'estimator__n_estimators': [100, 150, 200],
            'estimator__learning_rate': [0.01, 0.1, 0.2],
            'estimator__max_depth': [3, 5, 7]
        }
    },
    'KNeighborsRegressor': {
        'model': KNeighborsRegressor(),
        'params': {
            'n_neighbors': [3, 5, 7, 10],
            'weights': ['uniform', 'distance']
        }
    }
}

# Function to create combined dataset with given ratio for each floor
def create_combined_dataset(actual_data, synthetic_data, ratio):
    combined_data = pd.DataFrame()
    floors = actual_data['z'].unique()
    for floor in floors:
        actual_floor_data = actual_data[actual_data['z'] == floor]
        synthetic_floor_data = synthetic_data[synthetic_data['z'] == floor]
        
        n_actual = int(len(actual_floor_data) * ratio)
        n_synthetic = len(actual_floor_data) - n_actual
        
        actual_sample = actual_floor_data.sample(n_actual, random_state=42)
        if len(synthetic_floor_data) < n_synthetic:
            synthetic_sample = synthetic_floor_data.sample(n_synthetic, replace=True, random_state=42)
        else:
            synthetic_sample = synthetic_floor_data.sample(n_synthetic, random_state=42)
        
        combined_floor_data = pd.concat([actual_sample, synthetic_sample])
        combined_data = pd.concat([combined_data, combined_floor_data], ignore_index=True)
        
    return combined_data

# Function to perform grid search and train the model
def train_model_with_grid_search(X_train, y_train, model_config):
    grid_search = GridSearchCV(model_config['model'], model_config['params'], cv=10, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X_train, y_train)
    return grid_search.best_estimator_, -grid_search.best_score_

# Function to calculate Mean Distance Error
def mean_distance_error(y_true, y_pred):
    return np.mean(np.sqrt(np.sum((y_true - y_pred) ** 2, axis=1)))

# Train and evaluate models
ratios = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]
datasets = {
    'actual_ml': synthetic_data_ml,
    'actual_gan': synthetic_data_gan,
    'actual_ml_gan': synthetic_data_combined
}
results = {}

for dataset_name, synthetic_data in datasets.items():
    for ratio in ratios:
        combined_data = create_combined_dataset(actual_data, synthetic_data, ratio)
        
        # Floor classification training and evaluation
        X_train, X_test, y_train, y_test = train_test_split(combined_data[[f'RSSI{i+1}' for i in range(18)]], combined_data['z'], test_size=0.3, random_state=42)
        for model_name, model_config in classification_models.items():
            start_time = time.time()
            process = psutil.Process()
            initial_memory = process.memory_info().rss / (1024 ** 2)  # Convert to MB
            
            best_model, best_score = train_model_with_grid_search(X_train, y_train, model_config)
            
            training_time = time.time() - start_time
            training_memory = (process.memory_info().rss / (1024 ** 2)) - initial_memory
            
            start_time = time.time()
            initial_memory = process.memory_info().rss / (1024 ** 2)
            y_pred = best_model.predict(X_test)
            
            prediction_time = time.time() - start_time
            prediction_memory = (process.memory_info().rss / (1024 ** 2)) - initial_memory
            
            mae = mean_absolute_error(y_test, y_pred)
            
            results[f'{dataset_name}_{ratio}_{model_name}_floor'] = {
                'Mean Absolute Error': mae,
                'Training Time (s)': training_time,
                'Prediction Time (s)': prediction_time,
                'Memory Usage During Training (MB)': training_memory,
                'Memory Usage During Prediction (MB)': prediction_memory
            }
            dump(best_model, f'NEW_senior_saved_model/{dataset_name}_{ratio}_{model_name}_floor.joblib')
        
        # Coordinate regression training and evaluation
        X_train, X_test, y_train, y_test = train_test_split(combined_data[[f'RSSI{i+1}' for i in range(18)]], combined_data[['x', 'y']], test_size=0.3, random_state=42)
        for model_name, model_config in regression_models.items():
            start_time = time.time()
            process = psutil.Process()
            initial_memory = process.memory_info().rss / (1024 ** 2)  # Convert to MB
            
            best_model, best_score = train_model_with_grid_search(X_train, y_train, model_config)
            
            training_time = time.time() - start_time
            training_memory = (process.memory_info().rss / (1024 ** 2)) - initial_memory
            
            start_time = time.time()
            initial_memory = process.memory_info().rss / (1024 ** 2)
            y_pred = best_model.predict(X_test)
            
            prediction_time = time.time() - start_time
            prediction_memory = (process.memory_info().rss / (1024 ** 2)) - initial_memory
            
            mde = mean_distance_error(y_test, y_pred)
            
            results[f'{dataset_name}_{ratio}_{model_name}_coord'] = {
                'Mean Distance Error (meters)': mde,
                'Training Time (s)': training_time,
                'Prediction Time (s)': prediction_time,
                'Memory Usage During Training (MB)': training_memory,
                'Memory Usage During Prediction (MB)': prediction_memory
            }
            dump(best_model, f'NEW_senior_saved_model/{dataset_name}_{ratio}_{model_name}_coord.joblib')

# Print results
for key, metrics in results.items():
    print(f'Results for {key}:')
    for metric_name, value in metrics.items():
        print(f'  {metric_name}: {value}')

# Load and test models using the whole actual data
def load_and_predict_with_model(model_path, test_data, is_coordinate_model=False):
    model = load(model_path)
    X_test = test_data[[f'RSSI{i+1}' for i in range(18)]]
    
    process = psutil.Process()
    start_time = time.time()
    initial_memory = process.memory_info().rss / (1024 ** 2)  # Convert to MB

    predictions = model.predict(X_test)
    
    prediction_time = time.time() - start_time
    prediction_memory = (process.memory_info().rss / (1024 ** 2)) - initial_memory

    if is_coordinate_model:
        y_test = test_data[['x', 'y']]
        mean_dist_error = mean_distance_error(y_test, predictions)
        return {
            'Predictions': predictions,
            'Mean Distance Error (meters)': mean_dist_error,
            'Prediction Time (s)': prediction_time,
            'Memory Usage During Prediction (MB)': prediction_memory
        }
    else:
        y_test = test_data['z']
        mae = mean_absolute_error(y_test, predictions)
        return {
            'Predictions': predictions,
            'Mean Absolute Error': mae,
            'Prediction Time (s)': prediction_time,
            'Memory Usage During Prediction (MB)': prediction_memory
        }

# Example usage of the load_and_predict_with_model function
prediction_results = {}
model_directory = 'NEW_senior_saved_model'
classification_model_names = list(classification_models.keys())
regression_model_names = list(regression_models.keys())
dataset_names = list(datasets.keys())
ratios = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

# Split the actual data to get a test set
test_data = actual_data  # Using the whole actual data as test set

# Load and predict using each stored model
for model_name in classification_model_names:
    for dataset_name in dataset_names:
        for ratio in ratios:
            model_path = f'{model_directory}/{dataset_name}_{ratio}_{model_name}_floor.joblib'
            key = f'{dataset_name}_{ratio}_{model_name}_floor'
            prediction_results[key] = load_and_predict_with_model(model_path, test_data)
            print(f"Results for {key}:")
            for metric_name, value in prediction_results[key].items():
                print(f"  {metric_name}: {value}")

for model_name in regression_model_names:
    for dataset_name in dataset_names:
        for ratio in ratios:
            model_path = f'{model_directory}/{dataset_name}_{ratio}_{model_name}_coord.joblib'
            key = f'{dataset_name}_{ratio}_{model_name}_coord'
            prediction_results[key] = load_and_predict_with_model(model_path, test_data, is_coordinate_model=True)
            print(f"Results for {key}:")
            for metric_name, value in prediction_results[key].items():
                print(f"  {metric_name}: {value}")
# Out:
# Results for actual_ml_0.9_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 3.8678674697875977
#   Prediction Time (s): 0.004002094268798828
#   Memory Usage During Training (MB): 1.1796875
#   Memory Usage During Prediction (MB): 0.02734375
# Results for actual_ml_0.9_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.09585976600646973
#   Prediction Time (s): 0.0020020008087158203
#   Memory Usage During Training (MB): 0.3515625
#   Memory Usage During Prediction (MB): 0.0078125
# Results for actual_ml_0.9_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.003401360544217687
#   Training Time (s): 0.07765507698059082
#   Prediction Time (s): 0.000949859619140625
#   Memory Usage During Training (MB): 0.00390625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.9_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 5.255338191986084
#   Prediction Time (s): 0.0020055770874023438
#   Memory Usage During Training (MB): 0.36328125
#   Memory Usage During Prediction (MB): 0.03125
# Results for actual_ml_0.9_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.2605259418487549
#   Prediction Time (s): 0.26216626167297363
#   Memory Usage During Training (MB): 0.0078125
#   Memory Usage During Prediction (MB): -0.7109375
# Results for actual_ml_0.9_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0982296536429785
#   Training Time (s): 18.515889406204224
#   Prediction Time (s): 0.025156259536743164
#   Memory Usage During Training (MB): 21.375
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.9_LinearRegression_coord:
#   Mean Distance Error (meters): 4.201668013551345
#   Training Time (s): 0.029812335968017578
#   Prediction Time (s): 0.0010006427764892578
#   Memory Usage During Training (MB): -20.8984375
#   Memory Usage During Prediction (MB): 0.03515625
# Results for actual_ml_0.9_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.1392596045440444
#   Training Time (s): 0.11866974830627441
#   Prediction Time (s): 0.0009996891021728516
#   Memory Usage During Training (MB): 2.59765625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.9_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.0685319867557719
#   Training Time (s): 13.306498050689697
#   Prediction Time (s): 0.013765096664428711
#   Memory Usage During Training (MB): 1.59765625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.9_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.0187463303232713
#   Training Time (s): 0.0734097957611084
#   Prediction Time (s): 0.09357523918151855
#   Memory Usage During Training (MB): -7.0
#   Memory Usage During Prediction (MB): 1.16015625
# Results for actual_ml_0.8_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 1.7438645362854004
#   Prediction Time (s): 0.0030736923217773438
#   Memory Usage During Training (MB): 1.16015625
#   Memory Usage During Prediction (MB): 0.1171875
# Results for actual_ml_0.8_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.09002900123596191
#   Prediction Time (s): 0.0009999275207519531
#   Memory Usage During Training (MB): -0.16015625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.8_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.07753109931945801
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.01171875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.8_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 6.712989330291748
#   Prediction Time (s): 0.002001523971557617
#   Memory Usage During Training (MB): 0.28515625
#   Memory Usage During Prediction (MB): 0.11328125
# Results for actual_ml_0.8_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.0705406665802002
#   Prediction Time (s): 0.0939640998840332
#   Memory Usage During Training (MB): 0.00390625
#   Memory Usage During Prediction (MB): -0.90234375
# Results for actual_ml_0.8_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0694083095338178
#   Training Time (s): 26.35009503364563
#   Prediction Time (s): 0.09376740455627441
#   Memory Usage During Training (MB): 51.1640625
#   Memory Usage During Prediction (MB): 0.03125
# Results for actual_ml_0.8_LinearRegression_coord:
#   Mean Distance Error (meters): 4.060952336145102
#   Training Time (s): 0.048972368240356445
#   Prediction Time (s): 0.0029969215393066406
#   Memory Usage During Training (MB): -52.94921875
#   Memory Usage During Prediction (MB): 0.03515625
# Results for actual_ml_0.8_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.1284897346284652
#   Training Time (s): 0.1948862075805664
#   Prediction Time (s): 0.0027399063110351562
#   Memory Usage During Training (MB): 3.01953125
#   Memory Usage During Prediction (MB): 0.03515625
# Results for actual_ml_0.8_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.0520929692335361
#   Training Time (s): 19.067726373672485
#   Prediction Time (s): 0.017500877380371094
#   Memory Usage During Training (MB): 2.62890625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.8_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9649210755556662
#   Training Time (s): 0.08885455131530762
#   Prediction Time (s): 0.061064720153808594
#   Memory Usage During Training (MB): -7.359375
#   Memory Usage During Prediction (MB): 3.99609375
# Results for actual_ml_0.7_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.396655797958374
#   Prediction Time (s): 0.012068510055541992
#   Memory Usage During Training (MB): 2.19921875
#   Memory Usage During Prediction (MB): 0.12890625
# Results for actual_ml_0.7_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.10537958145141602
#   Prediction Time (s): 0.0010001659393310547
#   Memory Usage During Training (MB): -0.34375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.7_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.09195232391357422
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.47265625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.7_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 8.54446268081665
#   Prediction Time (s): 0.001985311508178711
#   Memory Usage During Training (MB): 0.3515625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_0.7_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.08000850677490234
#   Prediction Time (s): 0.09920382499694824
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -1.9375
# Results for actual_ml_0.7_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0569585940153772
#   Training Time (s): 32.4923369884491
#   Prediction Time (s): 0.061675071716308594
#   Memory Usage During Training (MB): 64.078125
#   Memory Usage During Prediction (MB): 0.01953125
# Results for actual_ml_0.7_LinearRegression_coord:
#   Mean Distance Error (meters): 3.8892414802503743
#   Training Time (s): 0.044985055923461914
#   Prediction Time (s): 0.0019991397857666016
#   Memory Usage During Training (MB): -68.21875
#   Memory Usage During Prediction (MB): 0.01953125
# Results for actual_ml_0.7_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.4156982439147552
#   Training Time (s): 0.19844794273376465
#   Prediction Time (s): 0.002000093460083008
#   Memory Usage During Training (MB): 2.96484375
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_ml_0.7_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.0413887425975041
#   Training Time (s): 25.70207667350769
#   Prediction Time (s): 0.011047124862670898
#   Memory Usage During Training (MB): 2.60546875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.7_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9973397947415521
#   Training Time (s): 0.07933950424194336
#   Prediction Time (s): 0.09410214424133301
#   Memory Usage During Training (MB): -4.1171875
#   Memory Usage During Prediction (MB): 1.62890625
# Results for actual_ml_0.6_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.3674795627593994
#   Prediction Time (s): 0.007992029190063477
#   Memory Usage During Training (MB): 2.2890625
#   Memory Usage During Prediction (MB): 0.109375
# Results for actual_ml_0.6_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.08791756629943848
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): -0.3359375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.6_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.09498810768127441
#   Prediction Time (s): 0.0010004043579101562
#   Memory Usage During Training (MB): 0.48828125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.6_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 9.53810429573059
#   Prediction Time (s): 0.002009153366088867
#   Memory Usage During Training (MB): 0.265625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.6_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.08067893981933594
#   Prediction Time (s): 0.12644076347351074
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -1.56640625
# Results for actual_ml_0.6_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0089337645687924
#   Training Time (s): 35.92184114456177
#   Prediction Time (s): 0.04245567321777344
#   Memory Usage During Training (MB): 51.48828125
#   Memory Usage During Prediction (MB): 0.0078125
# Results for actual_ml_0.6_LinearRegression_coord:
#   Mean Distance Error (meters): 3.724108318809784
#   Training Time (s): 0.04377555847167969
#   Prediction Time (s): 0.0019922256469726562
#   Memory Usage During Training (MB): -53.19140625
#   Memory Usage During Prediction (MB): 0.02734375
# Results for actual_ml_0.6_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.3667756120078451
#   Training Time (s): 0.18164491653442383
#   Prediction Time (s): 0.001995563507080078
#   Memory Usage During Training (MB): 2.6953125
#   Memory Usage During Prediction (MB): 0.0078125
# Results for actual_ml_0.6_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.9530585031757876
#   Training Time (s): 25.336575508117676
#   Prediction Time (s): 0.008760929107666016
#   Memory Usage During Training (MB): 1.24609375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.6_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9589072668977406
#   Training Time (s): 0.06969261169433594
#   Prediction Time (s): 0.08888030052185059
#   Memory Usage During Training (MB): -2.6484375
#   Memory Usage During Prediction (MB): 3.484375
# Results for actual_ml_0.5_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.1583127975463867
#   Prediction Time (s): 0.0038299560546875
#   Memory Usage During Training (MB): -12.55078125
#   Memory Usage During Prediction (MB): 0.13671875
# Results for actual_ml_0.5_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.07937097549438477
#   Prediction Time (s): 0.0014595985412597656
#   Memory Usage During Training (MB): 2.62890625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.5_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.08037590980529785
#   Prediction Time (s): 0.0010020732879638672
#   Memory Usage During Training (MB): 0.26171875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.5_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 10.192019939422607
#   Prediction Time (s): 0.0020096302032470703
#   Memory Usage During Training (MB): 0.1484375
#   Memory Usage During Prediction (MB): 0.12109375
# Results for actual_ml_0.5_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06897425651550293
#   Prediction Time (s): 0.09372115135192871
#   Memory Usage During Training (MB): 0.01171875
#   Memory Usage During Prediction (MB): 0.68359375
# Results for actual_ml_0.5_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.9486096950029775
#   Training Time (s): 41.30928158760071
#   Prediction Time (s): 0.058984994888305664
#   Memory Usage During Training (MB): 71.66015625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.5_LinearRegression_coord:
#   Mean Distance Error (meters): 3.5223383320196096
#   Training Time (s): 0.03394031524658203
#   Prediction Time (s): 0.0019578933715820312
#   Memory Usage During Training (MB): -74.3828125
#   Memory Usage During Prediction (MB): 0.01953125
# Results for actual_ml_0.5_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.1088143542026667
#   Training Time (s): 0.20788192749023438
#   Prediction Time (s): 0.0010466575622558594
#   Memory Usage During Training (MB): 2.671875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.5_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.985092848960107
#   Training Time (s): 30.103328466415405
#   Prediction Time (s): 0.010733366012573242
#   Memory Usage During Training (MB): 2.25390625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.5_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9208155300431539
#   Training Time (s): 0.06922245025634766
#   Prediction Time (s): 0.08361124992370605
#   Memory Usage During Training (MB): -4.17578125
#   Memory Usage During Prediction (MB): 1.3203125
# Results for actual_ml_0.4_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.2455289363861084
#   Prediction Time (s): 0.0036716461181640625
#   Memory Usage During Training (MB): -11.4609375
#   Memory Usage During Prediction (MB): 0.140625
# Results for actual_ml_0.4_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.07970643043518066
#   Prediction Time (s): 0.0010068416595458984
#   Memory Usage During Training (MB): 2.515625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.4_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.07859301567077637
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.23828125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.4_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 9.976680994033813
#   Prediction Time (s): 0.00099945068359375
#   Memory Usage During Training (MB): 0.828125
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_ml_0.4_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06764006614685059
#   Prediction Time (s): 0.09304475784301758
#   Memory Usage During Training (MB): 0.078125
#   Memory Usage During Prediction (MB): -0.80859375
# Results for actual_ml_0.4_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.8872067380643592
#   Training Time (s): 45.393059730529785
#   Prediction Time (s): 0.08418893814086914
#   Memory Usage During Training (MB): 73.76171875
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.4_LinearRegression_coord:
#   Mean Distance Error (meters): 3.252580509966943
#   Training Time (s): 0.05238509178161621
#   Prediction Time (s): 0.003007650375366211
#   Memory Usage During Training (MB): -79.37890625
#   Memory Usage During Prediction (MB): 0.0234375
# Results for actual_ml_0.4_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.3659678107247528
#   Training Time (s): 0.23265790939331055
#   Prediction Time (s): 0.0010018348693847656
#   Memory Usage During Training (MB): 2.72265625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_0.4_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.9287891389110224
#   Training Time (s): 33.848814487457275
#   Prediction Time (s): 0.010731935501098633
#   Memory Usage During Training (MB): 2.90234375
#   Memory Usage During Prediction (MB): 0.05078125
# Results for actual_ml_0.4_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.8653165339637626
#   Training Time (s): 0.06912398338317871
#   Prediction Time (s): 0.08715248107910156
#   Memory Usage During Training (MB): -3.80078125
#   Memory Usage During Prediction (MB): 1.00390625
# Results for actual_ml_0.3_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.3037142753601074
#   Prediction Time (s): 0.003999948501586914
#   Memory Usage During Training (MB): -11.32421875
#   Memory Usage During Prediction (MB): 0.13671875
# Results for actual_ml_0.3_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.05450725555419922
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 2.03125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.3_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.06799054145812988
#   Prediction Time (s): 0.0010006427764892578
#   Memory Usage During Training (MB): 0.2421875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.3_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 10.18554973602295
#   Prediction Time (s): 0.0019974708557128906
#   Memory Usage During Training (MB): 0.390625
#   Memory Usage During Prediction (MB): 0.12109375
# Results for actual_ml_0.3_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06745553016662598
#   Prediction Time (s): 0.11359691619873047
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.03125
# Results for actual_ml_0.3_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.752926800646875
#   Training Time (s): 47.99059987068176
#   Prediction Time (s): 0.05691862106323242
#   Memory Usage During Training (MB): 78.2578125
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.3_LinearRegression_coord:
#   Mean Distance Error (meters): 2.9919565138061825
#   Training Time (s): 0.0324406623840332
#   Prediction Time (s): 0.0020389556884765625
#   Memory Usage During Training (MB): -82.203125
#   Memory Usage During Prediction (MB): 0.01953125
# Results for actual_ml_0.3_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.2429568804446396
#   Training Time (s): 0.21794795989990234
#   Prediction Time (s): 0.0009992122650146484
#   Memory Usage During Training (MB): 2.68359375
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_0.3_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.7876212618624826
#   Training Time (s): 37.76104378700256
#   Prediction Time (s): 0.01062917709350586
#   Memory Usage During Training (MB): 2.01171875
#   Memory Usage During Prediction (MB): 0.046875
# Results for actual_ml_0.3_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.7534560947678105
#   Training Time (s): 0.06832647323608398
#   Prediction Time (s): 0.0879061222076416
#   Memory Usage During Training (MB): -3.94140625
#   Memory Usage During Prediction (MB): 0.16796875
# Results for actual_ml_0.2_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.334217071533203
#   Prediction Time (s): 0.0040225982666015625
#   Memory Usage During Training (MB): -8.66015625
#   Memory Usage During Prediction (MB): 0.13671875
# Results for actual_ml_0.2_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.05509066581726074
#   Prediction Time (s): 0.0010080337524414062
#   Memory Usage During Training (MB): 2.03515625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.2_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.07867026329040527
#   Prediction Time (s): 0.001005411148071289
#   Memory Usage During Training (MB): 0.2578125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.2_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 9.99678111076355
#   Prediction Time (s): 0.0009226799011230469
#   Memory Usage During Training (MB): 0.3671875
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_0.2_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06746101379394531
#   Prediction Time (s): 0.10378241539001465
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.046875
# Results for actual_ml_0.2_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.6158348201953414
#   Training Time (s): 46.66844177246094
#   Prediction Time (s): 0.028434276580810547
#   Memory Usage During Training (MB): 38.8046875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.2_LinearRegression_coord:
#   Mean Distance Error (meters): 2.603784412522117
#   Training Time (s): 0.03139638900756836
#   Prediction Time (s): 0.001994609832763672
#   Memory Usage During Training (MB): -42.921875
#   Memory Usage During Prediction (MB): 0.0234375
# Results for actual_ml_0.2_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.0891078297733365
#   Training Time (s): 0.23532867431640625
#   Prediction Time (s): 0.0011470317840576172
#   Memory Usage During Training (MB): 2.69140625
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_ml_0.2_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.6669168838182132
#   Training Time (s): 37.563446283340454
#   Prediction Time (s): 0.0060842037200927734
#   Memory Usage During Training (MB): 0.8125
#   Memory Usage During Prediction (MB): 0.1484375
# Results for actual_ml_0.2_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.6413194298712267
#   Training Time (s): 0.05830097198486328
#   Prediction Time (s): 0.09867000579833984
#   Memory Usage During Training (MB): -9.2109375
#   Memory Usage During Prediction (MB): 2.87109375
# Results for actual_ml_0.1_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.332350254058838
#   Prediction Time (s): 0.002999544143676758
#   Memory Usage During Training (MB): -10.96875
#   Memory Usage During Prediction (MB): 0.1328125
# Results for actual_ml_0.1_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.053289175033569336
#   Prediction Time (s): 0.0009922981262207031
#   Memory Usage During Training (MB): 2.5078125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.1_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.07974553108215332
#   Prediction Time (s): 0.0009949207305908203
#   Memory Usage During Training (MB): 0.265625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.1_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 10.618438959121704
#   Prediction Time (s): 0.0019812583923339844
#   Memory Usage During Training (MB): 0.14453125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_ml_0.1_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.06905508041381836
#   Prediction Time (s): 0.10024309158325195
#   Memory Usage During Training (MB): 0.01171875
#   Memory Usage During Prediction (MB): -0.23828125
# Results for actual_ml_0.1_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.4539839040435699
#   Training Time (s): 49.86823868751526
#   Prediction Time (s): 0.029072999954223633
#   Memory Usage During Training (MB): 39.24609375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.1_LinearRegression_coord:
#   Mean Distance Error (meters): 2.3423964050647377
#   Training Time (s): 0.11866140365600586
#   Prediction Time (s): 0.0020008087158203125
#   Memory Usage During Training (MB): -44.33203125
#   Memory Usage During Prediction (MB): 0.0234375
# Results for actual_ml_0.1_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 0.6137210081767964
#   Training Time (s): 0.28186917304992676
#   Prediction Time (s): 0.003619670867919922
#   Memory Usage During Training (MB): 2.796875
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_ml_0.1_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.6240675259958041
#   Training Time (s): 43.43288969993591
#   Prediction Time (s): 0.007678031921386719
#   Memory Usage During Training (MB): 0.26171875
#   Memory Usage During Prediction (MB): 0.125
# Results for actual_ml_0.1_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.497917099346304
#   Training Time (s): 0.06743693351745605
#   Prediction Time (s): 0.10630559921264648
#   Memory Usage During Training (MB): 0.53515625
#   Memory Usage During Prediction (MB): -7.921875
# Results for actual_gan_0.9_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 1.6460471153259277
#   Prediction Time (s): 0.005980730056762695
#   Memory Usage During Training (MB): -7.03125
#   Memory Usage During Prediction (MB): 0.1328125
# Results for actual_gan_0.9_LogisticRegression_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 0.08964323997497559
#   Prediction Time (s): 0.0010135173797607422
#   Memory Usage During Training (MB): 2.5859375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.9_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.005442176870748299
#   Training Time (s): 0.06400871276855469
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.328125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.9_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 4.9521448612213135
#   Prediction Time (s): 0.0016591548919677734
#   Memory Usage During Training (MB): 0.42578125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.9_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.06787252426147461
#   Prediction Time (s): 0.09039759635925293
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -0.3046875
# Results for actual_gan_0.9_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.3206416307956308
#   Training Time (s): 18.06184720993042
#   Prediction Time (s): 0.02520465850830078
#   Memory Usage During Training (MB): 20.10546875
#   Memory Usage During Prediction (MB): 0.046875
# Results for actual_gan_0.9_LinearRegression_coord:
#   Mean Distance Error (meters): 4.326793135810211
#   Training Time (s): 0.029952287673950195
#   Prediction Time (s): 0.0019986629486083984
#   Memory Usage During Training (MB): -23.66015625
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_gan_0.9_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.4455443890077089
#   Training Time (s): 0.11562252044677734
#   Prediction Time (s): 0.001999378204345703
#   Memory Usage During Training (MB): 2.65625
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_gan_0.9_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.2663842818431619
#   Training Time (s): 12.89035964012146
#   Prediction Time (s): 0.010751962661743164
#   Memory Usage During Training (MB): 1.2265625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.9_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.245913337752236
#   Training Time (s): 0.06826472282409668
#   Prediction Time (s): 0.08408951759338379
#   Memory Usage During Training (MB): -4.04296875
#   Memory Usage During Prediction (MB): -2.71484375
# Results for actual_gan_0.8_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 1.8375275135040283
#   Prediction Time (s): 0.006016254425048828
#   Memory Usage During Training (MB): -7.06640625
#   Memory Usage During Prediction (MB): 0.140625
# Results for actual_gan_0.8_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.09283638000488281
#   Prediction Time (s): 0.0010013580322265625
#   Memory Usage During Training (MB): 2.51953125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.8_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.07662224769592285
#   Prediction Time (s): 0.0009944438934326172
#   Memory Usage During Training (MB): 0.1796875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.8_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 6.847652196884155
#   Prediction Time (s): 0.003002643585205078
#   Memory Usage During Training (MB): 0.58984375
#   Memory Usage During Prediction (MB): 0.1171875
# Results for actual_gan_0.8_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 0.06765866279602051
#   Prediction Time (s): 0.1166999340057373
#   Memory Usage During Training (MB): 0.0078125
#   Memory Usage During Prediction (MB): -1.48046875
# Results for actual_gan_0.8_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.4269519163159294
#   Training Time (s): 25.237118244171143
#   Prediction Time (s): 0.05333065986633301
#   Memory Usage During Training (MB): 53.953125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.8_LinearRegression_coord:
#   Mean Distance Error (meters): 4.390244441224013
#   Training Time (s): 0.03212714195251465
#   Prediction Time (s): 0.0010030269622802734
#   Memory Usage During Training (MB): -55.2890625
#   Memory Usage During Prediction (MB): 0.02734375
# Results for actual_gan_0.8_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.7893583600264673
#   Training Time (s): 0.1315772533416748
#   Prediction Time (s): 0.001995086669921875
#   Memory Usage During Training (MB): 2.515625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.8_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.3043314394646317
#   Training Time (s): 17.340898752212524
#   Prediction Time (s): 0.016799449920654297
#   Memory Usage During Training (MB): 1.59375
#   Memory Usage During Prediction (MB): 0.1796875
# Results for actual_gan_0.8_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.3653830147607282
#   Training Time (s): 0.0719766616821289
#   Prediction Time (s): 0.09055423736572266
#   Memory Usage During Training (MB): -3.81640625
#   Memory Usage During Prediction (MB): 2.078125
# Results for actual_gan_0.7_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 1.9819316864013672
#   Prediction Time (s): 0.008992671966552734
#   Memory Usage During Training (MB): -10.71484375
#   Memory Usage During Prediction (MB): 0.140625
# Results for actual_gan_0.7_LogisticRegression_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 0.09658169746398926
#   Prediction Time (s): 0.001010894775390625
#   Memory Usage During Training (MB): 2.0859375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.7_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.005442176870748299
#   Training Time (s): 0.08209371566772461
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.2890625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.7_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 7.9314610958099365
#   Prediction Time (s): 0.0019998550415039062
#   Memory Usage During Training (MB): 0.1953125
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_gan_0.7_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.07057881355285645
#   Prediction Time (s): 0.09451103210449219
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.70703125
# Results for actual_gan_0.7_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.6216269015750062
#   Training Time (s): 29.431317806243896
#   Prediction Time (s): 0.03874063491821289
#   Memory Usage During Training (MB): 50.35546875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.7_LinearRegression_coord:
#   Mean Distance Error (meters): 4.337670569494083
#   Training Time (s): 0.030812740325927734
#   Prediction Time (s): 0.002000570297241211
#   Memory Usage During Training (MB): -54.62109375
#   Memory Usage During Prediction (MB): 0.01953125
# Results for actual_gan_0.7_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.239301165566179
#   Training Time (s): 0.15939688682556152
#   Prediction Time (s): 0.00099945068359375
#   Memory Usage During Training (MB): 2.75
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_gan_0.7_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.6164156650722603
#   Training Time (s): 22.226343393325806
#   Prediction Time (s): 0.01605963706970215
#   Memory Usage During Training (MB): 2.28515625
#   Memory Usage During Prediction (MB): 0.15625
# Results for actual_gan_0.7_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.5881793233994046
#   Training Time (s): 0.07251906394958496
#   Prediction Time (s): 0.09942173957824707
#   Memory Usage During Training (MB): -4.0859375
#   Memory Usage During Prediction (MB): 0.640625
# Results for actual_gan_0.6_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 2.3980965614318848
#   Prediction Time (s): 0.008082151412963867
#   Memory Usage During Training (MB): -9.640625
#   Memory Usage During Prediction (MB): 0.13671875
# Results for actual_gan_0.6_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.10894632339477539
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 2.05859375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.6_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.0835103988647461
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.2421875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.6_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 9.807316780090332
#   Prediction Time (s): 0.002992391586303711
#   Memory Usage During Training (MB): 0.36328125
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_gan_0.6_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.06860733032226562
#   Prediction Time (s): 0.09899306297302246
#   Memory Usage During Training (MB): 0.20703125
#   Memory Usage During Prediction (MB): -0.76953125
# Results for actual_gan_0.6_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.7179533988236744
#   Training Time (s): 31.515166997909546
#   Prediction Time (s): 0.029757976531982422
#   Memory Usage During Training (MB): 36.14453125
#   Memory Usage During Prediction (MB): 0.01171875
# Results for actual_gan_0.6_LinearRegression_coord:
#   Mean Distance Error (meters): 4.224930309074885
#   Training Time (s): 0.03352785110473633
#   Prediction Time (s): 0.002091646194458008
#   Memory Usage During Training (MB): -39.33203125
#   Memory Usage During Prediction (MB): 0.0234375
# Results for actual_gan_0.6_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.2821335322501635
#   Training Time (s): 0.17654681205749512
#   Prediction Time (s): 0.0009918212890625
#   Memory Usage During Training (MB): 2.6796875
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.6_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.7048820956859494
#   Training Time (s): 25.005918264389038
#   Prediction Time (s): 0.011667728424072266
#   Memory Usage During Training (MB): 2.38671875
#   Memory Usage During Prediction (MB): 0.0703125
# Results for actual_gan_0.6_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.7534128743555861
#   Training Time (s): 0.06925606727600098
#   Prediction Time (s): 0.10069823265075684
#   Memory Usage During Training (MB): -4.18359375
#   Memory Usage During Prediction (MB): 1.76171875
# Results for actual_gan_0.5_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 2.6123340129852295
#   Prediction Time (s): 0.008013010025024414
#   Memory Usage During Training (MB): -10.28125
#   Memory Usage During Prediction (MB): 0.1328125
# Results for actual_gan_0.5_LogisticRegression_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.11615467071533203
#   Prediction Time (s): 0.0009312629699707031
#   Memory Usage During Training (MB): 2.4921875
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_gan_0.5_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.004081632653061225
#   Training Time (s): 0.07979488372802734
#   Prediction Time (s): 0.001585245132446289
#   Memory Usage During Training (MB): 0.23828125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.5_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 10.369052410125732
#   Prediction Time (s): 0.003122091293334961
#   Memory Usage During Training (MB): 0.28125
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_gan_0.5_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.06805753707885742
#   Prediction Time (s): 0.12119698524475098
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -0.12890625
# Results for actual_gan_0.5_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.9060912258974911
#   Training Time (s): 40.26346254348755
#   Prediction Time (s): 0.055573225021362305
#   Memory Usage During Training (MB): 79.37109375
#   Memory Usage During Prediction (MB): 0.04296875
# Results for actual_gan_0.5_LinearRegression_coord:
#   Mean Distance Error (meters): 4.2496597950573936
#   Training Time (s): 0.045873165130615234
#   Prediction Time (s): 0.002990245819091797
#   Memory Usage During Training (MB): -84.5078125
#   Memory Usage During Prediction (MB): 0.0234375
# Results for actual_gan_0.5_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.423870022632866
#   Training Time (s): 0.21077919006347656
#   Prediction Time (s): 0.0020198822021484375
#   Memory Usage During Training (MB): 2.73046875
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.5_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.8678431838404081
#   Training Time (s): 28.418822050094604
#   Prediction Time (s): 0.011004924774169922
#   Memory Usage During Training (MB): 2.53125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.5_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.909717611277868
#   Training Time (s): 0.0684041976928711
#   Prediction Time (s): 0.10441970825195312
#   Memory Usage During Training (MB): -3.87890625
#   Memory Usage During Prediction (MB): 1.91796875
# Results for actual_gan_0.4_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.003401360544217687
#   Training Time (s): 2.8227486610412598
#   Prediction Time (s): 0.008008003234863281
#   Memory Usage During Training (MB): -9.6640625
#   Memory Usage During Prediction (MB): 0.1328125
# Results for actual_gan_0.4_LogisticRegression_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.08196306228637695
#   Prediction Time (s): 0.0010085105895996094
#   Memory Usage During Training (MB): 2.546875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.4_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.005442176870748299
#   Training Time (s): 0.08572149276733398
#   Prediction Time (s): 0.0010001659393310547
#   Memory Usage During Training (MB): 0.24609375
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.4_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.006122448979591836
#   Training Time (s): 11.740439653396606
#   Prediction Time (s): 0.0020008087158203125
#   Memory Usage During Training (MB): 0.67578125
#   Memory Usage During Prediction (MB): 0.1015625
# Results for actual_gan_0.4_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.004761904761904762
#   Training Time (s): 0.06756281852722168
#   Prediction Time (s): 0.09310245513916016
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -0.76953125
# Results for actual_gan_0.4_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.946523854001808
#   Training Time (s): 44.709532260894775
#   Prediction Time (s): 0.055815935134887695
#   Memory Usage During Training (MB): 86.921875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.4_LinearRegression_coord:
#   Mean Distance Error (meters): 4.2942646828832185
#   Training Time (s): 0.03626561164855957
#   Prediction Time (s): 0.0029892921447753906
#   Memory Usage During Training (MB): -92.34765625
#   Memory Usage During Prediction (MB): 0.01953125
# Results for actual_gan_0.4_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.693323599273805
#   Training Time (s): 0.22209930419921875
#   Prediction Time (s): 0.0016121864318847656
#   Memory Usage During Training (MB): 2.39453125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.4_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.9265324402083277
#   Training Time (s): 32.40009832382202
#   Prediction Time (s): 0.013851642608642578
#   Memory Usage During Training (MB): 1.98046875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.4_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.9768793864778496
#   Training Time (s): 0.06834292411804199
#   Prediction Time (s): 0.10399127006530762
#   Memory Usage During Training (MB): -3.8984375
#   Memory Usage During Prediction (MB): 2.0625
# Results for actual_gan_0.3_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 2.790499210357666
#   Prediction Time (s): 0.004997730255126953
#   Memory Usage During Training (MB): -9.484375
#   Memory Usage During Prediction (MB): 0.1328125
# Results for actual_gan_0.3_LogisticRegression_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.10255217552185059
#   Prediction Time (s): 0.001013040542602539
#   Memory Usage During Training (MB): 2.11328125
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.3_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.005442176870748299
#   Training Time (s): 0.08408951759338379
#   Prediction Time (s): 0.001001119613647461
#   Memory Usage During Training (MB): 0.23046875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.3_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 13.065102577209473
#   Prediction Time (s): 0.002996683120727539
#   Memory Usage During Training (MB): 0.6015625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.3_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.0694890022277832
#   Prediction Time (s): 0.10103869438171387
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -1.36328125
# Results for actual_gan_0.3_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.918030738760899
#   Training Time (s): 46.757039070129395
#   Prediction Time (s): 0.0443272590637207
#   Memory Usage During Training (MB): 68.43359375
#   Memory Usage During Prediction (MB): 0.0234375
# Results for actual_gan_0.3_LinearRegression_coord:
#   Mean Distance Error (meters): 4.152642678310018
#   Training Time (s): 0.03292655944824219
#   Prediction Time (s): 0.002000570297241211
#   Memory Usage During Training (MB): -74.390625
#   Memory Usage During Prediction (MB): 0.01953125
# Results for actual_gan_0.3_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.653885308489846
#   Training Time (s): 0.2345414161682129
#   Prediction Time (s): 0.000949859619140625
#   Memory Usage During Training (MB): 2.8984375
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.3_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.87243369661843
#   Training Time (s): 36.306753158569336
#   Prediction Time (s): 0.011632919311523438
#   Memory Usage During Training (MB): 1.81640625
#   Memory Usage During Prediction (MB): 0.24609375
# Results for actual_gan_0.3_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.979755485862896
#   Training Time (s): 0.06863045692443848
#   Prediction Time (s): 0.09855461120605469
#   Memory Usage During Training (MB): -3.80078125
#   Memory Usage During Prediction (MB): 1.515625
# Results for actual_gan_0.2_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 3.1180107593536377
#   Prediction Time (s): 0.006000995635986328
#   Memory Usage During Training (MB): 0.484375
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.2_LogisticRegression_floor:
#   Mean Absolute Error: 0.003401360544217687
#   Training Time (s): 0.12993669509887695
#   Prediction Time (s): 0.001020193099975586
#   Memory Usage During Training (MB): -0.35546875
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.2_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.005442176870748299
#   Training Time (s): 0.09776163101196289
#   Prediction Time (s): 0.0010066032409667969
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.2_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 14.500075817108154
#   Prediction Time (s): 0.0029752254486083984
#   Memory Usage During Training (MB): 0.5703125
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.2_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.004081632653061225
#   Training Time (s): 0.0694732666015625
#   Prediction Time (s): 0.11147522926330566
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): -7.27734375
# Results for actual_gan_0.2_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.9940054852406084
#   Training Time (s): 49.65822720527649
#   Prediction Time (s): 0.04448580741882324
#   Memory Usage During Training (MB): 73.5625
#   Memory Usage During Prediction (MB): 0.01953125
# Results for actual_gan_0.2_LinearRegression_coord:
#   Mean Distance Error (meters): 4.096690465585033
#   Training Time (s): 0.044712066650390625
#   Prediction Time (s): 0.0020003318786621094
#   Memory Usage During Training (MB): -75.93359375
#   Memory Usage During Prediction (MB): 0.01953125
# Results for actual_gan_0.2_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.8251620587379023
#   Training Time (s): 0.24187803268432617
#   Prediction Time (s): 0.0010061264038085938
#   Memory Usage During Training (MB): 2.1640625
#   Memory Usage During Prediction (MB): 0.09765625
# Results for actual_gan_0.2_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.896631181813632
#   Training Time (s): 39.67294883728027
#   Prediction Time (s): 0.011649847030639648
#   Memory Usage During Training (MB): 2.18359375
#   Memory Usage During Prediction (MB): 0.14453125
# Results for actual_gan_0.2_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 2.0921705978249716
#   Training Time (s): 0.0692892074584961
#   Prediction Time (s): 0.09023499488830566
#   Memory Usage During Training (MB): -4.04296875
#   Memory Usage During Prediction (MB): 1.51953125
# Results for actual_gan_0.1_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 3.1389694213867188
#   Prediction Time (s): 0.006005287170410156
#   Memory Usage During Training (MB): -6.03125
#   Memory Usage During Prediction (MB): 0.1328125
# Results for actual_gan_0.1_LogisticRegression_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.17138361930847168
#   Prediction Time (s): 0.0009951591491699219
#   Memory Usage During Training (MB): -0.3515625
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.1_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.004761904761904762
#   Training Time (s): 0.0842442512512207
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.0
#   Memory Usage During Prediction (MB): 0.0
# ...
#  [-8.81445964e-02 -1.61078605e-02]
#  [-8.81445964e-02 -1.61078605e-02]
#  ...
#  [ 8.80967401e+00  1.79942836e+01]
#  [ 9.72952238e+00  1.77593359e+01]
#  [ 9.72952238e+00  1.77593359e+01]]
#   Mean Distance Error (meters): 1.0522590095666031
#   Prediction Time (s): 0.024711132049560547
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_gan_0.5_GradientBoostingRegressor_coord:
#   Predictions: [[-0.09250815  0.13460278]
#  [-0.63155799  1.69409559]
#  [-0.63155799  1.69409559]
#  ...
#  [ 8.29521453 17.43713499]
#  [ 9.08892735 17.60824304]
#  [ 9.08892735 17.60824304]]
#   Mean Distance Error (meters): 1.1888067767304626
#   Prediction Time (s): 0.0230252742767334
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.4_GradientBoostingRegressor_coord:
#   Predictions: [[-0.10753577  0.29614453]
#  [ 0.42406099  0.70734087]
#  [ 0.42406099  0.70734087]
#  ...
#  [ 6.98137723 18.13903455]
#  [ 9.54254065 18.03177844]
#  [ 9.54254065 18.03177844]]
#   Mean Distance Error (meters): 1.3868057695464384
#   Prediction Time (s): 0.02269124984741211
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_gan_0.3_GradientBoostingRegressor_coord:
#   Predictions: [[-0.11990251  0.20094391]
#  [-0.71556311 -0.03936197]
#  [-0.71556311 -0.03936197]
#  ...
#  [ 6.07493877 17.69154025]
#  [ 8.75210847 17.96246643]
#  [ 8.75210847 17.96246643]]
#   Mean Distance Error (meters): 1.5657944261374837
#   Prediction Time (s): 0.02198624610900879
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.2_GradientBoostingRegressor_coord:
#   Predictions: [[-0.29523555  0.23902403]
#  [-1.89698868  1.50550417]
#  [-1.89698868  1.50550417]
#  ...
#  [ 6.09945189 18.62355712]
#  [ 4.56407956 19.05545184]
#  [ 4.56407956 19.05545184]]
#   Mean Distance Error (meters): 1.8677103525942538
#   Prediction Time (s): 0.022064685821533203
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.1_GradientBoostingRegressor_coord:
#   Predictions: [[-0.168186    0.26230222]
#  [-2.13536317  7.85805929]
#  [-2.13536317  7.85805929]
#  ...
#  [ 2.69821755 21.39075976]
#  [ 2.88307443 21.63969911]
#  [ 2.88307443 21.63969911]]
#   Mean Distance Error (meters): 2.3998067368265272
#   Prediction Time (s): 0.02400040626525879
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.9_GradientBoostingRegressor_coord:
#   Predictions: [[ 0.08685527  0.03799313]
#  [-0.05270024 -0.04797545]
#  [-0.05270024 -0.04797545]
#  ...
#  [ 9.58793844 17.58716883]
#  [ 9.57190779 17.48015452]
#  [ 9.57190779 17.48015452]]
#   Mean Distance Error (meters): 0.6426190341024912
#   Prediction Time (s): 0.023600339889526367
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_gan_0.8_GradientBoostingRegressor_coord:
#   Predictions: [[ 0.06956065  0.03689182]
#  [-0.05264417  0.04133169]
#  [-0.05264417  0.04133169]
#  ...
#  [ 9.23009201 17.54805328]
#  [ 9.46117907 17.41044211]
#  [ 9.46117907 17.41044211]]
#   Mean Distance Error (meters): 0.7084743956978062
#   Prediction Time (s): 0.02366042137145996
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.7_GradientBoostingRegressor_coord:
#   Predictions: [[-0.04156197 -0.05381602]
#  [-0.03604154  0.02258425]
#  [-0.03604154  0.02258425]
#  ...
#  [ 9.54226643 18.36276071]
#  [ 9.66564174 17.62752389]
#  [ 9.66564174 17.62752389]]
#   Mean Distance Error (meters): 0.7963958161583334
#   Prediction Time (s): 0.023755788803100586
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.6_GradientBoostingRegressor_coord:
#   Predictions: [[-3.66779786e-03  6.96828737e-02]
#  [-5.66858330e-02 -4.29078865e-02]
#  [-5.66858330e-02 -4.29078865e-02]
#  ...
#  [ 8.29334720e+00  1.86204005e+01]
#  [ 9.98473264e+00  1.73007255e+01]
#  [ 9.98473264e+00  1.73007255e+01]]
#   Mean Distance Error (meters): 0.9130157351265926
#   Prediction Time (s): 0.024588346481323242
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_gan_0.5_GradientBoostingRegressor_coord:
#   Predictions: [[ 1.00308937e-02  1.40376850e-01]
#  [-5.93213398e-01  9.92441379e-01]
#  [-5.93213398e-01  9.92441379e-01]
#  ...
#  [ 9.26968319e+00  1.94364710e+01]
#  [ 9.90407905e+00  1.74431112e+01]
#  [ 9.90407905e+00  1.74431112e+01]]
#   Mean Distance Error (meters): 1.2226414166512645
#   Prediction Time (s): 0.016049861907958984
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_gan_0.4_GradientBoostingRegressor_coord:
#   Predictions: [[-0.07286267  0.17318968]
#  [-0.15854533  0.88200658]
#  [-0.15854533  0.88200658]
#  ...
#  [ 9.72396061 19.39762609]
#  [ 9.67543514 17.52523822]
#  [ 9.67543514 17.52523822]]
#   Mean Distance Error (meters): 1.2401577314615162
#   Prediction Time (s): 0.023688554763793945
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.3_GradientBoostingRegressor_coord:
#   Predictions: [[-0.0484142   0.08192179]
#  [ 0.08052587  1.87861413]
#  [ 0.08052587  1.87861413]
#  ...
#  [ 6.13110891 11.36624483]
#  [ 8.97148364 17.46381585]
#  [ 8.97148364 17.46381585]]
#   Mean Distance Error (meters): 1.5092197166097217
#   Prediction Time (s): 0.023967266082763672
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_gan_0.2_GradientBoostingRegressor_coord:
#   Predictions: [[-0.08987503  0.0485834 ]
#  [-0.19348119  5.19939437]
#  [-0.19348119  5.19939437]
#  ...
#  [ 3.74535212 13.28602526]
#  [ 3.24767954 17.36558746]
#  [ 3.24767954 17.36558746]]
#   Mean Distance Error (meters): 1.8237139631093524
#   Prediction Time (s): 0.023682832717895508
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.1_GradientBoostingRegressor_coord:
#   Predictions: [[-0.30197414  0.20691383]
#  [-1.31107221 10.40460314]
#  [-1.31107221 10.40460314]
#  ...
#  [ 2.29768511 13.60667028]
#  [ 2.15669802 16.2705163 ]
#  [ 2.15669802 16.2705163 ]]
#   Mean Distance Error (meters): 2.53366060499289
#   Prediction Time (s): 0.016018390655517578
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.9_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.39516824099268966
#   Prediction Time (s): 0.21683144569396973
#   Memory Usage During Prediction (MB): 0.00390625
# Results for actual_ml_0.8_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.47753026729855474
#   Prediction Time (s): 0.21941566467285156
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.7_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 6.95228728 17.79128531]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.6056437327995224
#   Prediction Time (s): 0.24016213417053223
#   Memory Usage During Prediction (MB): 0.01171875
# Results for actual_ml_0.6_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 7.29344717 17.7344253 ]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.7390462342435211
#   Prediction Time (s): 0.21654248237609863
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.5_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.09959199  0.14004077]
#  [ 0.09959199  0.14004077]
#  ...
#  [ 7.50504967 17.61739846]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.9062933071411513
#   Prediction Time (s): 0.21800708770751953
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.4_KNeighborsRegressor_coord:
#   Predictions: [[ 0.00000000e+00  0.00000000e+00]
#  [-7.18544463e-02 -2.82159581e-05]
#  [-7.18544463e-02 -2.82159581e-05]
#  ...
#  [ 7.78734149e+00  1.76379020e+01]
#  [ 9.30000019e+00  1.73999996e+01]
#  [ 9.30000019e+00  1.73999996e+01]]
#   Mean Distance Error (meters): 1.1249883134686918
#   Prediction Time (s): 0.22205400466918945
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.3_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [-0.04066426  0.09991899]
#  [-0.04066426  0.09991899]
#  ...
#  [ 8.26727568 17.5921017 ]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 1.3773005271669956
#   Prediction Time (s): 0.23064708709716797
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.2_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [-0.11467648 -0.04215302]
#  [-0.11467648 -0.04215302]
#  ...
#  [ 7.38877463 17.72178805]
#  [ 7.43078828 17.71493302]
#  [ 7.43078828 17.71493302]]
#   Mean Distance Error (meters): 1.6599001934025925
#   Prediction Time (s): 0.21207642555236816
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_0.1_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [-0.21755831  0.11048569]
#  [-0.21755831  0.11048569]
#  ...
#  [ 7.51711003 17.61100967]
#  [ 5.54969993 17.02579144]
#  [ 5.54969993 17.02579144]]
#   Mean Distance Error (meters): 2.0899374101572206
#   Prediction Time (s): 0.20850825309753418
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.9_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.3972763149522223
#   Prediction Time (s): 0.21869897842407227
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.8_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.4972631379072214
#   Prediction Time (s): 0.21508264541625977
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.7_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 6.95228728 17.79128531]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.6197358176862099
#   Prediction Time (s): 0.21773195266723633
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.6_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 6.99307592 18.08298866]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.7787947871603716
#   Prediction Time (s): 0.21732020378112793
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.5_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [-0.98763664  1.65678769]
#  [-0.98763664  1.65678769]
#  ...
#  [ 7.19814742 18.85975889]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.9669102600487439
#   Prediction Time (s): 0.2112138271331787
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.4_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [-1.5029358   1.05620082]
#  [-1.5029358   1.05620082]
#  ...
#  [ 7.35130492 19.15024168]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 1.2134541600349824
#   Prediction Time (s): 0.20894956588745117
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.3_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [-1.86054809  1.17295259]
#  [-1.86054809  1.17295259]
#  ...
#  [ 7.30287116 19.07442964]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 1.5059168674772563
#   Prediction Time (s): 0.21595478057861328
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.2_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [-1.75246287  1.19760004]
#  [-1.75246287  1.19760004]
#  ...
#  [ 5.94051397 21.1271615 ]
#  [ 5.12224217 20.13943469]
#  [ 5.12224217 20.13943469]]
#   Mean Distance Error (meters): 1.877088256580915
#   Prediction Time (s): 0.21596121788024902
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_gan_0.1_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [-1.80531342  1.74882158]
#  [-1.80531342  1.74882158]
#  ...
#  [ 4.85293081 20.16390787]
#  [ 4.97635914 19.49037027]
#  [ 4.97635914 19.49037027]]
#   Mean Distance Error (meters): 2.4660205418197423
#   Prediction Time (s): 0.19504022598266602
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.9_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.3938906920522387
#   Prediction Time (s): 0.2150895595550537
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.8_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.4898444104271139
#   Prediction Time (s): 0.22025156021118164
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.7_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 6.95228728 17.79128531]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.6051975627510442
#   Prediction Time (s): 0.22108674049377441
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.6_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  ...
#  [ 7.29344717 17.7344253 ]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.7385562176521616
#   Prediction Time (s): 0.2265491485595703
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.5_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.1190752   0.28023633]
#  [ 0.1190752   0.28023633]
#  ...
#  [ 7.55651539 17.63537777]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 0.9066638038764684
#   Prediction Time (s): 0.21547436714172363
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.4_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [-0.20006749  0.26673544]
#  [-0.20006749  0.26673544]
#  ...
#  [ 7.90909534 17.63181722]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 1.129455464529655
#   Prediction Time (s): 0.16962027549743652
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.3_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [-0.02050415  0.14037462]
#  [-0.02050415  0.14037462]
#  ...
#  [ 7.69051185 17.5151779 ]
#  [ 9.30000019 17.39999962]
#  [ 9.30000019 17.39999962]]
#   Mean Distance Error (meters): 1.3726497156420128
#   Prediction Time (s): 0.21166634559631348
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.2_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.17107831  0.18620512]
#  [ 0.17107831  0.18620512]
#  ...
#  [ 6.14874495 17.64336323]
#  [ 6.71840145 17.66060499]
#  [ 6.71840145 17.66060499]]
#   Mean Distance Error (meters): 1.6695155208368475
#   Prediction Time (s): 0.22067904472351074
#   Memory Usage During Prediction (MB): 0.0
# Results for actual_ml_gan_0.1_KNeighborsRegressor_coord:
#   Predictions: [[ 0.          0.        ]
#  [ 0.07057068  0.24300373]
#  [ 0.07057068  0.24300373]
#  ...
#  [ 6.77327271 17.57069239]
#  [ 6.77970619 17.57069311]
#  [ 6.77970619 17.57069311]]
#   Mean Distance Error (meters): 2.0961703220823305
#   Prediction Time (s): 0.20814895629882812
#   Memory Usage During Prediction (MB): 0.0

# %%
import numpy as np
import pandas as pd
import time
import psutil
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from joblib import dump, load
import os
from sklearn.multioutput import MultiOutputRegressor

# Load datasets
actual_data = pd.read_csv('original_CMKL1.csv')
synthetic_data_ml = pd.read_csv('synthetic_data_RandomSeaerch_Ensemble.csv')
synthetic_data_gan = pd.read_csv('GANs_synthetic_data.csv')

# Combine synthetic datasets for the ML+GAN case
synthetic_data_combined = pd.concat([synthetic_data_ml, synthetic_data_gan])

# Create directory for saving models
if not os.path.exists('NEW_senior_saved_model'):
    os.makedirs('NEW_senior_saved_model')

# Define models and hyperparameters for grid search
classification_models = {
    'RandomForestClassifier': {
        'model': RandomForestClassifier(random_state=42),
        'params': {
            'n_estimators': [100, 150, 200],
            'max_depth': [10, 15, 20],
            'min_samples_split': [2, 5, 10]
        }
    },
    'LogisticRegression': {
        'model': LogisticRegression(random_state=42, max_iter=1000),
        'params': {
            'C': [0.01, 0.1, 1, 10, 100]
        }
    },
    'DecisionTreeClassifier': {
        'model': DecisionTreeClassifier(random_state=42),
        'params': {
            'max_depth': [10, 15, 20],
            'min_samples_split': [2, 5, 10]
        }
    },
    'GradientBoostingClassifier': {
        'model': GradientBoostingClassifier(random_state=42),
        'params': {
            'n_estimators': [100, 150, 200],
            'learning_rate': [0.01, 0.1, 0.2],
            'max_depth': [3, 5, 7]
        }
    },
    'KNeighborsClassifier': {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [3, 5, 7, 10],
            'weights': ['uniform', 'distance']
        }
    }
}

regression_models = {
    'RandomForestRegressor': {
        'model': MultiOutputRegressor(RandomForestRegressor(random_state=42)),
        'params': {
            'estimator__n_estimators': [100, 150, 200],
            'estimator__max_depth': [10, 15, 20],
            'estimator__min_samples_split': [2, 5, 10]
        }
    },
    'LinearRegression': {
        'model': MultiOutputRegressor(LinearRegression()),
        'params': {
            'estimator__fit_intercept': [True, False]
        }
    },
    'DecisionTreeRegressor': {
        'model': MultiOutputRegressor(DecisionTreeRegressor(random_state=42)),
        'params': {
            'estimator__max_depth': [10, 15, 20],
            'estimator__min_samples_split': [2, 5, 10]
        }
    },
    'GradientBoostingRegressor': {
        'model': MultiOutputRegressor(GradientBoostingRegressor(random_state=42)),
        'params': {
            'estimator__n_estimators': [100, 150, 200],
            'estimator__learning_rate': [0.01, 0.1, 0.2],
            'estimator__max_depth': [3, 5, 7]
        }
    },
    'KNeighborsRegressor': {
        'model': KNeighborsRegressor(),
        'params': {
            'n_neighbors': [3, 5, 7, 10],
            'weights': ['uniform', 'distance']
        }
    }
}

# Function to create combined dataset with given ratio for each floor
def create_combined_dataset(actual_data, synthetic_data, ratio):
    combined_data = pd.DataFrame()
    floors = actual_data['z'].unique()
    for floor in floors:
        actual_floor_data = actual_data[actual_data['z'] == floor]
        synthetic_floor_data = synthetic_data[synthetic_data['z'] == floor]
        
        n_actual = int(len(actual_floor_data) * ratio)
        n_synthetic = len(actual_floor_data) - n_actual
        
        actual_sample = actual_floor_data.sample(n_actual, random_state=42)
        if len(synthetic_floor_data) < n_synthetic:
            synthetic_sample = synthetic_floor_data.sample(n_synthetic, replace=True, random_state=42)
        else:
            synthetic_sample = synthetic_floor_data.sample(n_synthetic, random_state=42)
        
        combined_floor_data = pd.concat([actual_sample, synthetic_sample])
        combined_data = pd.concat([combined_data, combined_floor_data], ignore_index=True)
        
    return combined_data

# Function to perform grid search and train the model
def train_model_with_grid_search(X_train, y_train, model_config):
    grid_search = GridSearchCV(model_config['model'], model_config['params'], cv=10, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X_train, y_train)
    return grid_search.best_estimator_, -grid_search.best_score_, grid_search.best_params_

# Function to calculate Mean Distance Error
def mean_distance_error(y_true, y_pred):
    return np.mean(np.sqrt(np.sum((y_true - y_pred) ** 2, axis=1)))

# Train and evaluate models
ratios = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]
datasets = {
    'actual_ml': synthetic_data_ml,
    'actual_gan': synthetic_data_gan,
    'actual_ml_gan': synthetic_data_combined
}
results = {}

for dataset_name, synthetic_data in datasets.items():
    for ratio in ratios:
        combined_data = create_combined_dataset(actual_data, synthetic_data, ratio)
        
        # Floor classification training and evaluation
        X_train, X_test, y_train, y_test = train_test_split(combined_data[[f'RSSI{i+1}' for i in range(18)]], combined_data['z'], test_size=0.3, random_state=42)
        for model_name, model_config in classification_models.items():
            start_time = time.time()
            process = psutil.Process()
            initial_memory = process.memory_info().rss / (1024 ** 2)  # Convert to MB
            
            best_model, best_score, best_params = train_model_with_grid_search(X_train, y_train, model_config)
            
            training_time = time.time() - start_time
            final_memory = process.memory_info().rss / (1024 ** 2)
            training_memory = max(0, final_memory - initial_memory)  # Ensure memory usage is not negative
            
            start_time = time.time()
            initial_memory = process.memory_info().rss / (1024 ** 2)
            y_pred = best_model.predict(X_test)
            
            prediction_time = time.time() - start_time
            final_memory = process.memory_info().rss / (1024 ** 2)
            prediction_memory = max(0, final_memory - initial_memory)  # Ensure memory usage is not negative
            
            mae = mean_absolute_error(y_test, y_pred)
            
            results[f'{dataset_name}_{ratio}_{model_name}_floor'] = {
                'Mean Absolute Error': mae,
                'Training Time (s)': training_time,
                'Prediction Time (s)': prediction_time,
                'Memory Usage During Training (MB)': training_memory,
                'Memory Usage During Prediction (MB)': prediction_memory,
                'Best Parameters': best_params
            }
            dump(best_model, f'NEW_senior_saved_model/{dataset_name}_{ratio}_{model_name}_floor.joblib')
        
        # Coordinate regression training and evaluation
        X_train, X_test, y_train, y_test = train_test_split(combined_data[[f'RSSI{i+1}' for i in range(18)]], combined_data[['x', 'y']], test_size=0.3, random_state=42)
        for model_name, model_config in regression_models.items():
            start_time = time.time()
            process = psutil.Process()
            initial_memory = process.memory_info().rss / (1024 ** 2)  # Convert to MB
            
            best_model, best_score, best_params = train_model_with_grid_search(X_train, y_train, model_config)
            
            training_time = time.time() - start_time
            final_memory = process.memory_info().rss / (1024 ** 2)
            training_memory = max(0, final_memory - initial_memory)  # Ensure memory usage is not negative
            
            start_time = time.time()
            initial_memory = process.memory_info().rss / (1024 ** 2)
            y_pred = best_model.predict(X_test)
            
            prediction_time = time.time() - start_time
            final_memory = process.memory_info().rss / (1024 ** 2)
            prediction_memory = max(0, final_memory - initial_memory)  # Ensure memory usage is not negative
            
            mde = mean_distance_error(y_test, y_pred)
            
            results[f'{dataset_name}_{ratio}_{model_name}_coord'] = {
                'Mean Distance Error (meters)': mde,
                'Training Time (s)': training_time,
                'Prediction Time (s)': prediction_time,
                'Memory Usage During Training (MB)': training_memory,
                'Memory Usage During Prediction (MB)': prediction_memory,
                'Best Parameters': best_params
            }
            dump(best_model, f'NEW_senior_saved_model/{dataset_name}_{ratio}_{model_name}_coord.joblib')

# Print results
for key, metrics in results.items():
    print(f'Results for {key}:')
    for metric_name, value in metrics.items():
        print(f'  {metric_name}: {value}')

# Load and test models using the whole actual data
def load_and_predict_with_model(model_path, test_data, is_coordinate_model=False):
    model = load(model_path)
    X_test = test_data[[f'RSSI{i+1}' for i in range(18)]]
    
    process = psutil.Process()
    start_time = time.time()
    initial_memory = process.memory_info().rss / (1024 ** 2)  # Convert to MB

    predictions = model.predict(X_test)
    
    prediction_time = time.time() - start_time
    final_memory = process.memory_info().rss / (1024 ** 2)
    prediction_memory = max(0, final_memory - initial_memory)  # Ensure memory usage is not negative

    if is_coordinate_model:
        y_test = test_data[['x', 'y']]
        mean_dist_error = mean_distance_error(y_test, predictions)
        return {
            'Predictions': predictions,
            'Mean Distance Error (meters)': mean_dist_error,
            'Prediction Time (s)': prediction_time,
            'Memory Usage During Prediction (MB)': prediction_memory
        }
    else:
        y_test = test_data['z']
        mae = mean_absolute_error(y_test, predictions)
        return {
            'Predictions': predictions,
            'Mean Absolute Error': mae,
            'Prediction Time (s)': prediction_time,
            'Memory Usage During Prediction (MB)': prediction_memory
        }

# Example usage of the load_and_predict_with_model function
prediction_results = {}
model_directory = 'NEW_senior_saved_model'
classification_model_names = list(classification_models.keys())
regression_model_names = list(regression_models.keys())
dataset_names = list(datasets.keys())
ratios = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

# Split the actual data to get a test set
test_data = actual_data  # Using the whole actual data as test set

# Load and predict using each stored model
for model_name in classification_model_names:
    for dataset_name in dataset_names:
        for ratio in ratios:
            model_path = f'{model_directory}/{dataset_name}_{ratio}_{model_name}_floor.joblib'
            key = f'{dataset_name}_{ratio}_{model_name}_floor'
            prediction_results[key] = load_and_predict_with_model(model_path, test_data)
            print(f"Results for {key}:")
            for metric_name, value in prediction_results[key].items():
                print(f"  {metric_name}: {value}")

for model_name in regression_model_names:
    for dataset_name in dataset_names:
        for ratio in ratios:
            model_path = f'{model_directory}/{dataset_name}_{ratio}_{model_name}_coord.joblib'
            key = f'{dataset_name}_{ratio}_{model_name}_coord'
            prediction_results[key] = load_and_predict_with_model(model_path, test_data, is_coordinate_model=True)
            print(f"Results for {key}:")
            for metric_name, value in prediction_results[key].items():
                print(f"  {metric_name}: {value}")

# Display best parameters in a separate cell
best_params_results = {key: value['Best Parameters'] for key, value in results.items()}
best_params_results
# Out:
# Results for actual_ml_0.9_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 5.577222585678101
#   Prediction Time (s): 0.004059791564941406
#   Memory Usage During Training (MB): 2.45703125
#   Memory Usage During Prediction (MB): 0.06640625
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_ml_0.9_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.11963939666748047
#   Prediction Time (s): 0.0010411739349365234
#   Memory Usage During Training (MB): 0.37890625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'C': 0.01}
# Results for actual_ml_0.9_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.003401360544217687
#   Training Time (s): 0.12122726440429688
#   Prediction Time (s): 0.0009949207305908203
#   Memory Usage During Training (MB): 0.00390625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2}
# Results for actual_ml_0.9_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 10.895709753036499
#   Prediction Time (s): 0.0020105838775634766
#   Memory Usage During Training (MB): 0.44921875
#   Memory Usage During Prediction (MB): 0.03515625
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Results for actual_ml_0.9_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.3000001907348633
#   Prediction Time (s): 0.2438042163848877
#   Memory Usage During Training (MB): 0.01171875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 3, 'weights': 'uniform'}
# Results for actual_ml_0.9_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0961192080216888
#   Training Time (s): 43.41877222061157
#   Prediction Time (s): 0.0518183708190918
#   Memory Usage During Training (MB): 43.90234375
#   Memory Usage During Prediction (MB): 0.078125
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 200}
# Results for actual_ml_0.9_LinearRegression_coord:
#   Mean Distance Error (meters): 4.201668013551345
#   Training Time (s): 0.04587101936340332
#   Prediction Time (s): 0.003016948699951172
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.03515625
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_ml_0.9_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.2322231097520717
#   Training Time (s): 0.19975996017456055
#   Prediction Time (s): 0.0009982585906982422
#   Memory Usage During Training (MB): 1.38671875
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 5}
# Results for actual_ml_0.9_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.9214884619014024
#   Training Time (s): 26.216039180755615
#   Prediction Time (s): 0.011006832122802734
#   Memory Usage During Training (MB): 3.19921875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__learning_rate': 0.2, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_ml_0.9_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.0187463303238256
#   Training Time (s): 0.09441709518432617
#   Prediction Time (s): 0.08311128616333008
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 10, 'weights': 'distance'}
# Results for actual_ml_0.8_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 3.732001543045044
#   Prediction Time (s): 0.003995418548583984
#   Memory Usage During Training (MB): 0.09765625
#   Memory Usage During Prediction (MB): 0.00390625
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_ml_0.8_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.1097102165222168
#   Prediction Time (s): 0.0010759830474853516
#   Memory Usage During Training (MB): 0.00390625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'C': 0.01}
# Results for actual_ml_0.8_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.12316274642944336
#   Prediction Time (s): 0.0005905628204345703
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2}
# Results for actual_ml_0.8_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 14.751091003417969
#   Prediction Time (s): 0.0019965171813964844
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.171875
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Results for actual_ml_0.8_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.10278177261352539
#   Prediction Time (s): 0.10963082313537598
#   Memory Usage During Training (MB): 1.0703125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 3, 'weights': 'uniform'}
# Results for actual_ml_0.8_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0713699246944992
#   Training Time (s): 54.46335005760193
#   Prediction Time (s): 0.03867983818054199
#   Memory Usage During Training (MB): 37.265625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 150}
# Results for actual_ml_0.8_LinearRegression_coord:
#   Mean Distance Error (meters): 4.060952336145104
#   Training Time (s): 0.04210162162780762
#   Prediction Time (s): 0.0010199546813964844
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.046875
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_ml_0.8_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.212874173885521
#   Training Time (s): 0.2533290386199951
#   Prediction Time (s): 0.001013040542602539
#   Memory Usage During Training (MB): 2.0546875
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 5}
# Results for actual_ml_0.8_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.9343663637289001
#   Training Time (s): 39.21551465988159
#   Prediction Time (s): 0.011005401611328125
#   Memory Usage During Training (MB): 3.28125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__learning_rate': 0.2, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_ml_0.8_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9649210687408424
#   Training Time (s): 0.12099242210388184
#   Prediction Time (s): 0.08408975601196289
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.01171875
#   Best Parameters: {'n_neighbors': 5, 'weights': 'distance'}
# Results for actual_ml_0.7_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 4.016621112823486
#   Prediction Time (s): 0.004002094268798828
#   Memory Usage During Training (MB): 0.7109375
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_ml_0.7_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.12307333946228027
#   Prediction Time (s): 0.00099945068359375
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.03515625
#   Best Parameters: {'C': 0.01}
# Results for actual_ml_0.7_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.13733267784118652
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 2.8046875
#   Memory Usage During Prediction (MB): 0.109375
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2}
# Results for actual_ml_0.7_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 20.37010955810547
#   Prediction Time (s): 0.004019737243652344
#   Memory Usage During Training (MB): 0.81640625
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 150}
# Results for actual_ml_0.7_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.11362457275390625
#   Prediction Time (s): 0.12145137786865234
#   Memory Usage During Training (MB): 0.53125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 3, 'weights': 'uniform'}
# Results for actual_ml_0.7_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.0569585940153772
#   Training Time (s): 83.01391935348511
#   Prediction Time (s): 0.08117389678955078
#   Memory Usage During Training (MB): 60.98828125
#   Memory Usage During Prediction (MB): 0.015625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 200}
# Results for actual_ml_0.7_LinearRegression_coord:
#   Mean Distance Error (meters): 3.8892414802503743
#   Training Time (s): 0.059967041015625
#   Prediction Time (s): 0.003624439239501953
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.01953125
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_ml_0.7_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.1981848377147108
#   Training Time (s): 0.34068918228149414
#   Prediction Time (s): 0.002004384994506836
#   Memory Usage During Training (MB): 2.828125
#   Memory Usage During Prediction (MB): 0.046875
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2}
# Results for actual_ml_0.7_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.0413887425975041
#   Training Time (s): 54.02839374542236
#   Prediction Time (s): 0.0145263671875
#   Memory Usage During Training (MB): 2.890625
#   Memory Usage During Prediction (MB): 0.03125
#   Best Parameters: {'estimator__learning_rate': 0.1, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_ml_0.7_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9973397842084679
#   Training Time (s): 0.11975622177124023
#   Prediction Time (s): 0.09561467170715332
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.76953125
#   Best Parameters: {'n_neighbors': 7, 'weights': 'distance'}
# Results for actual_ml_0.6_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 5.229995250701904
#   Prediction Time (s): 0.008159875869750977
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.140625
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_ml_0.6_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.13934111595153809
#   Prediction Time (s): 0.0020551681518554688
#   Memory Usage During Training (MB): 2.9609375
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'C': 0.01}
# Results for actual_ml_0.6_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.1572566032409668
#   Prediction Time (s): 0.001001596450805664
#   Memory Usage During Training (MB): 0.23046875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 5}
# Results for actual_ml_0.6_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 25.06340217590332
#   Prediction Time (s): 0.0020079612731933594
#   Memory Usage During Training (MB): 0.15234375
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100}
# Results for actual_ml_0.6_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.12284517288208008
#   Prediction Time (s): 0.10607218742370605
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 7, 'weights': 'uniform'}
# Results for actual_ml_0.6_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.006410248771514
#   Training Time (s): 98.73942232131958
#   Prediction Time (s): 0.08479046821594238
#   Memory Usage During Training (MB): 71.8203125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 200}
# Results for actual_ml_0.6_LinearRegression_coord:
#   Mean Distance Error (meters): 3.724108318809784
#   Training Time (s): 0.19182085990905762
#   Prediction Time (s): 0.002009868621826172
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.015625
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_ml_0.6_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.4217941431350407
#   Training Time (s): 0.37824010848999023
#   Prediction Time (s): 0.0020105838775634766
#   Memory Usage During Training (MB): 2.51171875
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 10}
# Results for actual_ml_0.6_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.9973859312922636
#   Training Time (s): 66.50529050827026
#   Prediction Time (s): 0.015517950057983398
#   Memory Usage During Training (MB): 2.33984375
#   Memory Usage During Prediction (MB): 0.04296875
#   Best Parameters: {'estimator__learning_rate': 0.1, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_ml_0.6_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9589073179977682
#   Training Time (s): 0.11508560180664062
#   Prediction Time (s): 0.10435771942138672
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.828125
#   Best Parameters: {'n_neighbors': 5, 'weights': 'distance'}
# Results for actual_ml_0.5_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 5.718035697937012
#   Prediction Time (s): 0.0066640377044677734
#   Memory Usage During Training (MB): 0.41796875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_ml_0.5_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.14857697486877441
#   Prediction Time (s): 0.0009984970092773438
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'C': 0.01}
# Results for actual_ml_0.5_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 0.15022873878479004
#   Prediction Time (s): 0.0009672641754150391
#   Memory Usage During Training (MB): 2.6875
#   Memory Usage During Prediction (MB): 0.10546875
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2}
# Results for actual_ml_0.5_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 26.07078266143799
#   Prediction Time (s): 0.002000093460083008
#   Memory Usage During Training (MB): 0.55859375
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 150}
# Results for actual_ml_0.5_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.10138297080993652
#   Prediction Time (s): 0.08632087707519531
#   Memory Usage During Training (MB): 0.08203125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 7, 'weights': 'uniform'}
# Results for actual_ml_0.5_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.9564842241202419
#   Training Time (s): 88.28913402557373
#   Prediction Time (s): 0.0325772762298584
#   Memory Usage During Training (MB): 34.6328125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100}
# Results for actual_ml_0.5_LinearRegression_coord:
#   Mean Distance Error (meters): 3.522338332019611
#   Training Time (s): 0.05717945098876953
#   Prediction Time (s): 0.0020122528076171875
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.01953125
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_ml_0.5_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.1088143542026667
#   Training Time (s): 0.36190176010131836
#   Prediction Time (s): 0.000997304916381836
#   Memory Usage During Training (MB): 2.98828125
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2}
# Results for actual_ml_0.5_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.985092848960107
#   Training Time (s): 63.92505502700806
#   Prediction Time (s): 0.011529922485351562
#   Memory Usage During Training (MB): 1.76953125
#   Memory Usage During Prediction (MB): 0.17578125
#   Best Parameters: {'estimator__learning_rate': 0.1, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_ml_0.5_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.9208562036865934
#   Training Time (s): 0.09401893615722656
#   Prediction Time (s): 0.08114814758300781
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 5, 'weights': 'distance'}
# Results for actual_ml_0.4_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 4.923590421676636
#   Prediction Time (s): 0.0039594173431396484
#   Memory Usage During Training (MB): 0.66796875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_ml_0.4_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.12091922760009766
#   Prediction Time (s): 0.0009999275207519531
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'C': 0.01}
# Results for actual_ml_0.4_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.003401360544217687
#   Training Time (s): 0.13516449928283691
#   Prediction Time (s): 0.001001596450805664
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 5}
# Results for actual_ml_0.4_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 24.4172101020813
#   Prediction Time (s): 0.0019986629486083984
#   Memory Usage During Training (MB): 0.06640625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Results for actual_ml_0.4_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.10062670707702637
#   Prediction Time (s): 0.10802268981933594
#   Memory Usage During Training (MB): 0.01953125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 3, 'weights': 'uniform'}
# Results for actual_ml_0.4_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.8872067380643592
#   Training Time (s): 98.5949637889862
#   Prediction Time (s): 0.05702638626098633
#   Memory Usage During Training (MB): 74.31640625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 200}
# Results for actual_ml_0.4_LinearRegression_coord:
#   Mean Distance Error (meters): 3.2525805099669425
#   Training Time (s): 0.04492664337158203
#   Prediction Time (s): 0.003500699996948242
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.01953125
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_ml_0.4_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.2918217426335379
#   Training Time (s): 0.3718287944793701
#   Prediction Time (s): 0.001004934310913086
#   Memory Usage During Training (MB): 2.26953125
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 10}
# Results for actual_ml_0.4_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.9287891389110224
#   Training Time (s): 73.35036039352417
#   Prediction Time (s): 0.01142120361328125
#   Memory Usage During Training (MB): 2.34765625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__learning_rate': 0.1, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_ml_0.4_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.8653165669849927
#   Training Time (s): 0.0924520492553711
#   Prediction Time (s): 0.09272623062133789
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 7, 'weights': 'distance'}
# Results for actual_ml_0.3_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 5.082111597061157
#   Prediction Time (s): 0.004007577896118164
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.1328125
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_ml_0.3_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.0906822681427002
#   Prediction Time (s): 0.0009379386901855469
#   Memory Usage During Training (MB): 2.93359375
#   Memory Usage During Prediction (MB): 0.00390625
#   Best Parameters: {'C': 0.01}
# Results for actual_ml_0.3_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.1497187614440918
#   Prediction Time (s): 0.0009732246398925781
#   Memory Usage During Training (MB): 0.26171875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2}
# Results for actual_ml_0.3_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 24.884520053863525
#   Prediction Time (s): 0.002047300338745117
#   Memory Usage During Training (MB): 0.3046875
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Results for actual_ml_0.3_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.10318660736083984
#   Prediction Time (s): 0.09050703048706055
#   Memory Usage During Training (MB): 0.0859375
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 3, 'weights': 'uniform'}
# Results for actual_ml_0.3_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.7521142940765366
#   Training Time (s): 103.78196287155151
#   Prediction Time (s): 0.04316377639770508
#   Memory Usage During Training (MB): 58.37890625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 150}
# Results for actual_ml_0.3_LinearRegression_coord:
#   Mean Distance Error (meters): 2.9919565138061825
#   Training Time (s): 0.04702115058898926
#   Prediction Time (s): 0.0039026737213134766
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.0234375
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_ml_0.3_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.2429568804446396
#   Training Time (s): 0.3864011764526367
#   Prediction Time (s): 0.0010459423065185547
#   Memory Usage During Training (MB): 2.78125
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'estimator__max_depth': 10, 'estimator__min_samples_split': 2}
# Results for actual_ml_0.3_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.7457835976845985
#   Training Time (s): 78.95385956764221
#   Prediction Time (s): 0.01079249382019043
#   Memory Usage During Training (MB): 2.39453125
#   Memory Usage During Prediction (MB): 0.19921875
#   Best Parameters: {'estimator__learning_rate': 0.2, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_ml_0.3_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.7537962460138443
#   Training Time (s): 0.09082221984863281
#   Prediction Time (s): 0.07578659057617188
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 1.40625
#   Best Parameters: {'n_neighbors': 7, 'weights': 'distance'}
# Results for actual_ml_0.2_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 5.172376871109009
#   Prediction Time (s): 0.003687620162963867
#   Memory Usage During Training (MB): 0.3828125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_ml_0.2_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.0767526626586914
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.09375
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'C': 0.01}
# Results for actual_ml_0.2_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.1262044906616211
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2}
# Results for actual_ml_0.2_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 23.51013994216919
#   Prediction Time (s): 0.0019783973693847656
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.265625
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Results for actual_ml_0.2_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.09411168098449707
#   Prediction Time (s): 0.09840607643127441
#   Memory Usage During Training (MB): 2.27734375
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 3, 'weights': 'uniform'}
# Results for actual_ml_0.2_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.610310521226775
#   Training Time (s): 111.80596566200256
#   Prediction Time (s): 0.05649304389953613
#   Memory Usage During Training (MB): 80.13671875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 200}
# Results for actual_ml_0.2_LinearRegression_coord:
#   Mean Distance Error (meters): 2.60378441252212
#   Training Time (s): 0.04748988151550293
#   Prediction Time (s): 0.003233671188354492
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.0234375
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_ml_0.2_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 0.8285942815151204
#   Training Time (s): 0.4064369201660156
#   Prediction Time (s): 0.0010154247283935547
#   Memory Usage During Training (MB): 2.3515625
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'estimator__max_depth': 15, 'estimator__min_samples_split': 5}
# Results for actual_ml_0.2_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.6501147482865779
#   Training Time (s): 86.49834752082825
#   Prediction Time (s): 0.011701345443725586
#   Memory Usage During Training (MB): 2.59765625
#   Memory Usage During Prediction (MB): 0.02734375
#   Best Parameters: {'estimator__learning_rate': 0.1, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_ml_0.2_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.6562439892139041
#   Training Time (s): 0.09217524528503418
#   Prediction Time (s): 0.09630274772644043
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 1.91796875
#   Best Parameters: {'n_neighbors': 10, 'weights': 'distance'}
# Results for actual_ml_0.1_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 5.0613343715667725
#   Prediction Time (s): 0.0026259422302246094
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.13671875
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_ml_0.1_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.08231139183044434
#   Prediction Time (s): 0.001123189926147461
#   Memory Usage During Training (MB): 2.484375
#   Memory Usage During Prediction (MB): 0.00390625
#   Best Parameters: {'C': 0.01}
# Results for actual_ml_0.1_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.1280364990234375
#   Prediction Time (s): 0.0005071163177490234
#   Memory Usage During Training (MB): 0.2578125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2}
# Results for actual_ml_0.1_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 24.616670846939087
#   Prediction Time (s): 0.001997232437133789
#   Memory Usage During Training (MB): 0.1875
#   Memory Usage During Prediction (MB): 0.10546875
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Results for actual_ml_0.1_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.10099148750305176
#   Prediction Time (s): 0.07494688034057617
#   Memory Usage During Training (MB): 0.02734375
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 3, 'weights': 'uniform'}
# Results for actual_ml_0.1_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 0.4539839040435699
#   Training Time (s): 112.45897936820984
#   Prediction Time (s): 0.0302274227142334
#   Memory Usage During Training (MB): 39.515625
#   Memory Usage During Prediction (MB): 0.00390625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100}
# Results for actual_ml_0.1_LinearRegression_coord:
#   Mean Distance Error (meters): 2.3423964050647386
#   Training Time (s): 0.04558873176574707
#   Prediction Time (s): 0.002983570098876953
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.0234375
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_ml_0.1_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 0.6137210081767964
#   Training Time (s): 0.4415261745452881
#   Prediction Time (s): 0.0011053085327148438
#   Memory Usage During Training (MB): 2.51953125
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'estimator__max_depth': 15, 'estimator__min_samples_split': 5}
# Results for actual_ml_0.1_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 0.49041950237900983
#   Training Time (s): 93.30531883239746
#   Prediction Time (s): 0.010731935501098633
#   Memory Usage During Training (MB): 2.3671875
#   Memory Usage During Prediction (MB): 0.1484375
#   Best Parameters: {'estimator__learning_rate': 0.1, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_ml_0.1_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 0.4979171496156242
#   Training Time (s): 0.09238266944885254
#   Prediction Time (s): 0.08919191360473633
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 1.82421875
#   Best Parameters: {'n_neighbors': 10, 'weights': 'distance'}
# Results for actual_gan_0.9_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 3.427668571472168
#   Prediction Time (s): 0.004015922546386719
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.13671875
#   Best Parameters: {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 100}
# Results for actual_gan_0.9_LogisticRegression_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 0.11240839958190918
#   Prediction Time (s): 0.0015070438385009766
#   Memory Usage During Training (MB): 2.55859375
#   Memory Usage During Prediction (MB): 0.00390625
#   Best Parameters: {'C': 0.01}
# Results for actual_gan_0.9_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.005442176870748299
#   Training Time (s): 0.10719776153564453
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.2578125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2}
# Results for actual_gan_0.9_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 11.519174575805664
#   Prediction Time (s): 0.003000020980834961
#   Memory Usage During Training (MB): 0.99609375
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# Results for actual_gan_0.9_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.10138201713562012
#   Prediction Time (s): 0.09597587585449219
#   Memory Usage During Training (MB): 0.04296875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 10, 'weights': 'uniform'}
# Results for actual_gan_0.9_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.3182989943199364
#   Training Time (s): 41.73084282875061
#   Prediction Time (s): 0.03806591033935547
#   Memory Usage During Training (MB): 31.62109375
#   Memory Usage During Prediction (MB): 0.078125
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 150}
# Results for actual_gan_0.9_LinearRegression_coord:
#   Mean Distance Error (meters): 4.32679313581021
#   Training Time (s): 0.042875051498413086
#   Prediction Time (s): 0.001983165740966797
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.01171875
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_gan_0.9_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.476760905427791
#   Training Time (s): 0.19168972969055176
#   Prediction Time (s): 0.0009996891021728516
#   Memory Usage During Training (MB): 2.109375
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 5}
# Results for actual_gan_0.9_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.1171972375390755
#   Training Time (s): 26.74789547920227
#   Prediction Time (s): 0.010671377182006836
#   Memory Usage During Training (MB): 2.34375
#   Memory Usage During Prediction (MB): 0.0390625
#   Best Parameters: {'estimator__learning_rate': 0.2, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_gan_0.9_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.2399052359636944
#   Training Time (s): 0.09154272079467773
#   Prediction Time (s): 0.08885741233825684
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 1.13671875
#   Best Parameters: {'n_neighbors': 7, 'weights': 'distance'}
# Results for actual_gan_0.8_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 4.074853420257568
#   Prediction Time (s): 0.007674455642700195
#   Memory Usage During Training (MB): 0.78125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 200}
# Results for actual_gan_0.8_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.15350961685180664
#   Prediction Time (s): 0.0008904933929443359
#   Memory Usage During Training (MB): 0.09375
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'C': 0.01}
# Results for actual_gan_0.8_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.004081632653061225
#   Training Time (s): 0.12195324897766113
#   Prediction Time (s): 0.0009520053863525391
#   Memory Usage During Training (MB): 0.00390625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 15, 'min_samples_split': 5}
# Results for actual_gan_0.8_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 15.734708786010742
#   Prediction Time (s): 0.002002716064453125
#   Memory Usage During Training (MB): 0.35546875
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 150}
# Results for actual_gan_0.8_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 0.10183477401733398
#   Prediction Time (s): 0.09943389892578125
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 3, 'weights': 'uniform'}
# Results for actual_gan_0.8_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.4269519163159294
#   Training Time (s): 53.89434599876404
#   Prediction Time (s): 0.052036285400390625
#   Memory Usage During Training (MB): 54.15234375
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 200}
# Results for actual_gan_0.8_LinearRegression_coord:
#   Mean Distance Error (meters): 4.3902444412240165
#   Training Time (s): 0.04418444633483887
#   Prediction Time (s): 0.0027379989624023438
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.01953125
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_gan_0.8_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 1.5816561872757158
#   Training Time (s): 0.23251605033874512
#   Prediction Time (s): 0.0020170211791992188
#   Memory Usage During Training (MB): 3.015625
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 5}
# Results for actual_gan_0.8_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.4248533250579551
#   Training Time (s): 35.04539346694946
#   Prediction Time (s): 0.011356592178344727
#   Memory Usage During Training (MB): 1.94140625
#   Memory Usage During Prediction (MB): 0.0234375
#   Best Parameters: {'estimator__learning_rate': 0.1, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_gan_0.8_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.36538301476073
#   Training Time (s): 0.09295821189880371
#   Prediction Time (s): 0.08424663543701172
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 1.21875
#   Best Parameters: {'n_neighbors': 7, 'weights': 'distance'}
# Results for actual_gan_0.7_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 4.30657696723938
#   Prediction Time (s): 0.003999948501586914
#   Memory Usage During Training (MB): 0.89453125
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_gan_0.7_LogisticRegression_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 0.13208270072937012
#   Prediction Time (s): 0.0009992122650146484
#   Memory Usage During Training (MB): 3.1171875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'C': 0.01}
# Results for actual_gan_0.7_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.13703513145446777
#   Prediction Time (s): 0.0010001659393310547
#   Memory Usage During Training (MB): 0.2578125
#   Memory Usage During Prediction (MB): 0.10546875
#   Best Parameters: {'max_depth': 15, 'min_samples_split': 2}
# Results for actual_gan_0.7_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 18.908878087997437
#   Prediction Time (s): 0.0030364990234375
#   Memory Usage During Training (MB): 0.4609375
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 150}
# Results for actual_gan_0.7_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.003401360544217687
#   Training Time (s): 0.09627032279968262
#   Prediction Time (s): 0.10114455223083496
#   Memory Usage During Training (MB): 0.0390625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 10, 'weights': 'uniform'}
# Results for actual_gan_0.7_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.6204996798066105
#   Training Time (s): 65.14653134346008
#   Prediction Time (s): 0.052771806716918945
#   Memory Usage During Training (MB): 69.34375
#   Memory Usage During Prediction (MB): 0.00390625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 200}
# Results for actual_gan_0.7_LinearRegression_coord:
#   Mean Distance Error (meters): 4.337670569494085
#   Training Time (s): 0.04443073272705078
#   Prediction Time (s): 0.002789735794067383
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.01953125
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_gan_0.7_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.2176327708483186
#   Training Time (s): 0.26033830642700195
#   Prediction Time (s): 0.0011031627655029297
#   Memory Usage During Training (MB): 2.3828125
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 10}
# Results for actual_gan_0.7_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.5174984602612307
#   Training Time (s): 43.16979265213013
#   Prediction Time (s): 0.012485980987548828
#   Memory Usage During Training (MB): 2.41015625
#   Memory Usage During Prediction (MB): 0.1796875
#   Best Parameters: {'estimator__learning_rate': 0.2, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_gan_0.7_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.58817932339941
#   Training Time (s): 0.09499406814575195
#   Prediction Time (s): 0.08614373207092285
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.60546875
#   Best Parameters: {'n_neighbors': 7, 'weights': 'distance'}
# Results for actual_gan_0.6_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 4.9142165184021
#   Prediction Time (s): 0.004683732986450195
#   Memory Usage During Training (MB): 0.72265625
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_gan_0.6_LogisticRegression_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 0.15212750434875488
#   Prediction Time (s): 0.0
#   Memory Usage During Training (MB): 0.01171875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'C': 0.01}
# Results for actual_gan_0.6_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.14277243614196777
#   Prediction Time (s): 0.0010056495666503906
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 15, 'min_samples_split': 2}
# Results for actual_gan_0.6_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0
#   Training Time (s): 22.508066654205322
#   Prediction Time (s): 0.0020058155059814453
#   Memory Usage During Training (MB): 0.01171875
#   Memory Usage During Prediction (MB): 0.09765625
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Results for actual_gan_0.6_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0013605442176870747
#   Training Time (s): 0.10351300239562988
#   Prediction Time (s): 0.08423638343811035
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 7, 'weights': 'distance'}
# Results for actual_gan_0.6_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.7023770703248027
#   Training Time (s): 76.36933207511902
#   Prediction Time (s): 0.054132938385009766
#   Memory Usage During Training (MB): 73.296875
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 200}
# Results for actual_gan_0.6_LinearRegression_coord:
#   Mean Distance Error (meters): 4.2249303090748835
#   Training Time (s): 0.044356346130371094
#   Prediction Time (s): 0.0030002593994140625
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.01953125
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_gan_0.6_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.338197028844628
#   Training Time (s): 0.30446839332580566
#   Prediction Time (s): 0.0019838809967041016
#   Memory Usage During Training (MB): 2.7578125
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 10}
# Results for actual_gan_0.6_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.7048820956859494
#   Training Time (s): 51.624340772628784
#   Prediction Time (s): 0.011933565139770508
#   Memory Usage During Training (MB): 2.578125
#   Memory Usage During Prediction (MB): 0.19140625
#   Best Parameters: {'estimator__learning_rate': 0.1, 'estimator__max_depth': 7, 'estimator__n_estimators': 200}
# Results for actual_gan_0.6_KNeighborsRegressor_coord:
#   Mean Distance Error (meters): 1.7534128743556103
#   Training Time (s): 0.09024691581726074
#   Prediction Time (s): 0.07911229133605957
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.37109375
#   Best Parameters: {'n_neighbors': 7, 'weights': 'distance'}
# Results for actual_gan_0.5_RandomForestClassifier_floor:
#   Mean Absolute Error: 0.0006802721088435374
#   Training Time (s): 5.344364166259766
#   Prediction Time (s): 0.005008697509765625
#   Memory Usage During Training (MB): 0.6015625
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Results for actual_gan_0.5_LogisticRegression_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.15015792846679688
#   Prediction Time (s): 0.001009225845336914
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'C': 0.01}
# Results for actual_gan_0.5_DecisionTreeClassifier_floor:
#   Mean Absolute Error: 0.004081632653061225
#   Training Time (s): 0.14407658576965332
#   Prediction Time (s): 0.0010004043579101562
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'max_depth': 15, 'min_samples_split': 2}
# Results for actual_gan_0.5_GradientBoostingClassifier_floor:
#   Mean Absolute Error: 0.0020408163265306124
#   Training Time (s): 25.092069625854492
#   Prediction Time (s): 0.0017054080963134766
#   Memory Usage During Training (MB): 0.328125
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Results for actual_gan_0.5_KNeighborsClassifier_floor:
#   Mean Absolute Error: 0.0027210884353741495
#   Training Time (s): 0.10328149795532227
#   Prediction Time (s): 0.09357142448425293
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'n_neighbors': 7, 'weights': 'uniform'}
# Results for actual_gan_0.5_RandomForestRegressor_coord:
#   Mean Distance Error (meters): 1.9060912258974911
#   Training Time (s): 85.8826162815094
#   Prediction Time (s): 0.05509614944458008
#   Memory Usage During Training (MB): 79.265625
#   Memory Usage During Prediction (MB): 0
#   Best Parameters: {'estimator__max_depth': 20, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 200}
# Results for actual_gan_0.5_LinearRegression_coord:
#   Mean Distance Error (meters): 4.2496597950573936
#   Training Time (s): 0.04762840270996094
#   Prediction Time (s): 0.0029671192169189453
#   Memory Usage During Training (MB): 0
#   Memory Usage During Prediction (MB): 0.01953125
#   Best Parameters: {'estimator__fit_intercept': True}
# Results for actual_gan_0.5_DecisionTreeRegressor_coord:
#   Mean Distance Error (meters): 2.483266567533758
#   Training Time (s): 0.3311643600463867
#   Prediction Time (s): 0.0009903907775878906
#   Memory Usage During Training (MB): 2.92578125
#   Memory Usage During Prediction (MB): 0.1015625
#   Best Parameters: {'estimator__max_depth': 15, 'estimator__min_samples_split': 10}
# Results for actual_gan_0.5_GradientBoostingRegressor_coord:
#   Mean Distance Error (meters): 1.8678431838404081
#   Training Time (s): 59.177035331726074
#   Prediction Time (s): 0.010769844055175781
#   Memory Usage During Training (MB): 2.46875
#   Memory Usage During Prediction (MB): 0.17578125
# ...
#   'n_estimators': 100},
#  'actual_gan_0.6_LogisticRegression_floor': {'C': 0.01},
#  'actual_gan_0.6_DecisionTreeClassifier_floor': {'max_depth': 15,
#   'min_samples_split': 2},
#  'actual_gan_0.6_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_gan_0.6_KNeighborsClassifier_floor': {'n_neighbors': 7,
#   'weights': 'distance'},
#  'actual_gan_0.6_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.6_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_gan_0.6_DecisionTreeRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 10},
#  'actual_gan_0.6_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.6_KNeighborsRegressor_coord': {'n_neighbors': 7,
#   'weights': 'distance'},
#  'actual_gan_0.5_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_gan_0.5_LogisticRegression_floor': {'C': 0.01},
#  'actual_gan_0.5_DecisionTreeClassifier_floor': {'max_depth': 15,
#   'min_samples_split': 2},
#  'actual_gan_0.5_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_gan_0.5_KNeighborsClassifier_floor': {'n_neighbors': 7,
#   'weights': 'uniform'},
#  'actual_gan_0.5_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.5_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_gan_0.5_DecisionTreeRegressor_coord': {'estimator__max_depth': 15,
#   'estimator__min_samples_split': 10},
#  'actual_gan_0.5_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.5_KNeighborsRegressor_coord': {'n_neighbors': 7,
#   'weights': 'distance'},
#  'actual_gan_0.4_RandomForestClassifier_floor': {'max_depth': 15,
#   'min_samples_split': 2,
#   'n_estimators': 150},
#  'actual_gan_0.4_LogisticRegression_floor': {'C': 0.01},
#  'actual_gan_0.4_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 10},
#  'actual_gan_0.4_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_gan_0.4_KNeighborsClassifier_floor': {'n_neighbors': 5,
#   'weights': 'distance'},
#  'actual_gan_0.4_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 150},
#  'actual_gan_0.4_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_gan_0.4_DecisionTreeRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 10},
#  'actual_gan_0.4_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.4_KNeighborsRegressor_coord': {'n_neighbors': 7,
#   'weights': 'distance'},
#  'actual_gan_0.3_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_gan_0.3_LogisticRegression_floor': {'C': 0.01},
#  'actual_gan_0.3_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 10},
#  'actual_gan_0.3_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_gan_0.3_KNeighborsClassifier_floor': {'n_neighbors': 10,
#   'weights': 'distance'},
#  'actual_gan_0.3_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.3_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_gan_0.3_DecisionTreeRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 10},
#  'actual_gan_0.3_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.3_KNeighborsRegressor_coord': {'n_neighbors': 7,
#   'weights': 'distance'},
#  'actual_gan_0.2_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_gan_0.2_LogisticRegression_floor': {'C': 0.01},
#  'actual_gan_0.2_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 5},
#  'actual_gan_0.2_GradientBoostingClassifier_floor': {'learning_rate': 0.2,
#   'max_depth': 3,
#   'n_estimators': 150},
#  'actual_gan_0.2_KNeighborsClassifier_floor': {'n_neighbors': 5,
#   'weights': 'uniform'},
#  'actual_gan_0.2_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.2_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_gan_0.2_DecisionTreeRegressor_coord': {'estimator__max_depth': 10,
#   'estimator__min_samples_split': 10},
#  'actual_gan_0.2_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.2_KNeighborsRegressor_coord': {'n_neighbors': 7,
#   'weights': 'distance'},
#  'actual_gan_0.1_RandomForestClassifier_floor': {'max_depth': 15,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_gan_0.1_LogisticRegression_floor': {'C': 1},
#  'actual_gan_0.1_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 5},
#  'actual_gan_0.1_GradientBoostingClassifier_floor': {'learning_rate': 0.2,
#   'max_depth': 3,
#   'n_estimators': 150},
#  'actual_gan_0.1_KNeighborsClassifier_floor': {'n_neighbors': 3,
#   'weights': 'uniform'},
#  'actual_gan_0.1_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.1_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_gan_0.1_DecisionTreeRegressor_coord': {'estimator__max_depth': 15,
#   'estimator__min_samples_split': 10},
#  'actual_gan_0.1_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_gan_0.1_KNeighborsRegressor_coord': {'n_neighbors': 7,
#   'weights': 'distance'},
#  'actual_ml_gan_0.9_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_ml_gan_0.9_LogisticRegression_floor': {'C': 0.01},
#  'actual_ml_gan_0.9_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2},
#  'actual_ml_gan_0.9_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_ml_gan_0.9_KNeighborsClassifier_floor': {'n_neighbors': 3,
#   'weights': 'uniform'},
#  'actual_ml_gan_0.9_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.9_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_ml_gan_0.9_DecisionTreeRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 5},
#  'actual_ml_gan_0.9_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.9_KNeighborsRegressor_coord': {'n_neighbors': 10,
#   'weights': 'distance'},
#  'actual_ml_gan_0.8_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_ml_gan_0.8_LogisticRegression_floor': {'C': 0.01},
#  'actual_ml_gan_0.8_DecisionTreeClassifier_floor': {'max_depth': 15,
#   'min_samples_split': 2},
#  'actual_ml_gan_0.8_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_ml_gan_0.8_KNeighborsClassifier_floor': {'n_neighbors': 3,
#   'weights': 'uniform'},
#  'actual_ml_gan_0.8_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 150},
#  'actual_ml_gan_0.8_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_ml_gan_0.8_DecisionTreeRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2},
#  'actual_ml_gan_0.8_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.8_KNeighborsRegressor_coord': {'n_neighbors': 10,
#   'weights': 'distance'},
#  'actual_ml_gan_0.7_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_ml_gan_0.7_LogisticRegression_floor': {'C': 0.01},
#  'actual_ml_gan_0.7_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 10},
#  'actual_ml_gan_0.7_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 200},
#  'actual_ml_gan_0.7_KNeighborsClassifier_floor': {'n_neighbors': 3,
#   'weights': 'uniform'},
#  'actual_ml_gan_0.7_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.7_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_ml_gan_0.7_DecisionTreeRegressor_coord': {'estimator__max_depth': 15,
#   'estimator__min_samples_split': 5},
#  'actual_ml_gan_0.7_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.2,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.7_KNeighborsRegressor_coord': {'n_neighbors': 7,
#   'weights': 'distance'},
#  'actual_ml_gan_0.6_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_ml_gan_0.6_LogisticRegression_floor': {'C': 0.01},
#  'actual_ml_gan_0.6_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 10},
#  'actual_ml_gan_0.6_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 150},
#  'actual_ml_gan_0.6_KNeighborsClassifier_floor': {'n_neighbors': 7,
#   'weights': 'uniform'},
#  'actual_ml_gan_0.6_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.6_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_ml_gan_0.6_DecisionTreeRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 5},
#  'actual_ml_gan_0.6_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.6_KNeighborsRegressor_coord': {'n_neighbors': 5,
#   'weights': 'distance'},
#  'actual_ml_gan_0.5_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_ml_gan_0.5_LogisticRegression_floor': {'C': 0.01},
#  'actual_ml_gan_0.5_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2},
#  'actual_ml_gan_0.5_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_ml_gan_0.5_KNeighborsClassifier_floor': {'n_neighbors': 7,
#   'weights': 'uniform'},
#  'actual_ml_gan_0.5_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.5_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_ml_gan_0.5_DecisionTreeRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 10},
#  'actual_ml_gan_0.5_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.2,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 150},
#  'actual_ml_gan_0.5_KNeighborsRegressor_coord': {'n_neighbors': 5,
#   'weights': 'distance'},
#  'actual_ml_gan_0.4_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_ml_gan_0.4_LogisticRegression_floor': {'C': 0.01},
#  'actual_ml_gan_0.4_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2},
#  'actual_ml_gan_0.4_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_ml_gan_0.4_KNeighborsClassifier_floor': {'n_neighbors': 3,
#   'weights': 'uniform'},
#  'actual_ml_gan_0.4_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 150},
#  'actual_ml_gan_0.4_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_ml_gan_0.4_DecisionTreeRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 5},
#  'actual_ml_gan_0.4_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.2,
#   'estimator__max_depth': 5,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.4_KNeighborsRegressor_coord': {'n_neighbors': 7,
#   'weights': 'distance'},
#  'actual_ml_gan_0.3_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_ml_gan_0.3_LogisticRegression_floor': {'C': 0.01},
#  'actual_ml_gan_0.3_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2},
#  'actual_ml_gan_0.3_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_ml_gan_0.3_KNeighborsClassifier_floor': {'n_neighbors': 3,
#   'weights': 'uniform'},
#  'actual_ml_gan_0.3_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 100},
#  'actual_ml_gan_0.3_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_ml_gan_0.3_DecisionTreeRegressor_coord': {'estimator__max_depth': 15,
#   'estimator__min_samples_split': 10},
#  'actual_ml_gan_0.3_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.3_KNeighborsRegressor_coord': {'n_neighbors': 7,
#   'weights': 'distance'},
#  'actual_ml_gan_0.2_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_ml_gan_0.2_LogisticRegression_floor': {'C': 0.01},
#  'actual_ml_gan_0.2_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2},
#  'actual_ml_gan_0.2_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_ml_gan_0.2_KNeighborsClassifier_floor': {'n_neighbors': 3,
#   'weights': 'uniform'},
#  'actual_ml_gan_0.2_RandomForestRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 150},
#  'actual_ml_gan_0.2_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_ml_gan_0.2_DecisionTreeRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2},
#  'actual_ml_gan_0.2_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.2_KNeighborsRegressor_coord': {'n_neighbors': 10,
#   'weights': 'distance'},
#  'actual_ml_gan_0.1_RandomForestClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'actual_ml_gan_0.1_LogisticRegression_floor': {'C': 0.01},
#  'actual_ml_gan_0.1_DecisionTreeClassifier_floor': {'max_depth': 10,
#   'min_samples_split': 2},
#  'actual_ml_gan_0.1_GradientBoostingClassifier_floor': {'learning_rate': 0.1,
#   'max_depth': 3,
#   'n_estimators': 100},
#  'actual_ml_gan_0.1_KNeighborsClassifier_floor': {'n_neighbors': 3,
#   'weights': 'uniform'},
#  'actual_ml_gan_0.1_RandomForestRegressor_coord': {'estimator__max_depth': 15,
#   'estimator__min_samples_split': 2,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.1_LinearRegression_coord': {'estimator__fit_intercept': True},
#  'actual_ml_gan_0.1_DecisionTreeRegressor_coord': {'estimator__max_depth': 20,
#   'estimator__min_samples_split': 2},
#  'actual_ml_gan_0.1_GradientBoostingRegressor_coord': {'estimator__learning_rate': 0.1,
#   'estimator__max_depth': 7,
#   'estimator__n_estimators': 200},
#  'actual_ml_gan_0.1_KNeighborsRegressor_coord': {'n_neighbors': 10,
#   'weights': 'distance'}}
