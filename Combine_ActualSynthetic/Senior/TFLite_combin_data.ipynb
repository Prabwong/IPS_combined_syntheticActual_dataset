# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
from sklearn.model_selection import train_test_split, KFold
import shutil
import keras_tuner as kt

# Load datasets
actual_data = pd.read_csv('original_CMKL1.csv')
synthetic_data_ml = pd.read_csv('synthetic_data_RandomSeaerch_Ensemble.csv')
synthetic_data_gan = pd.read_csv('GANs_synthetic_data.csv')

# Combine synthetic datasets for the ML+GAN case
synthetic_data_combined = pd.concat([synthetic_data_ml, synthetic_data_gan])

# Create directory for saving models
if not os.path.exists('TFLite_NEW_senior_saved_model'):
    os.makedirs('TFLite_NEW_senior_saved_model')

# Define functions to build models in TensorFlow that approximate scikit-learn models

def build_logistic_regression(hp):
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(18,)),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

def build_decision_tree_classifier(hp):
    units = hp.Int('units', 32, 256, step=32)
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(18,)),
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

def build_decision_tree_regressor(hp):
    units = hp.Int('units', 32, 256, step=32)
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(18,)),
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                  loss='mean_squared_error')
    return model

def build_random_forest_classifier(hp):
    units1 = hp.Int('units1', 64, 256, step=32)
    units2 = hp.Int('units2', 32, 128, step=32)
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(18,)),
        tf.keras.layers.Dense(units1, activation='relu'),
        tf.keras.layers.Dense(units2, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

def build_random_forest_regressor(hp):
    units1 = hp.Int('units1', 64, 256, step=32)
    units2 = hp.Int('units2', 32, 128, step=32)
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(18,)),
        tf.keras.layers.Dense(units1, activation='relu'),
        tf.keras.layers.Dense(units2, activation='relu'),
        tf.keras.layers.Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                  loss='mean_squared_error')
    return model

def build_gradient_boosting_classifier(hp):
    units1 = hp.Int('units1', 64, 256, step=32)
    units2 = hp.Int('units2', 32, 128, step=32)
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(18,)),
        tf.keras.layers.Dense(units1, activation='relu'),
        tf.keras.layers.Dense(units2, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

def build_gradient_boosting_regressor(hp):
    units1 = hp.Int('units1', 64, 256, step=32)
    units2 = hp.Int('units2', 32, 128, step=32)
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(18,)),
        tf.keras.layers.Dense(units1, activation='relu'),
        tf.keras.layers.Dense(units2, activation='relu'),
        tf.keras.layers.Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                  loss='mean_squared_error')
    return model

def build_knn_classifier(hp):
    units1 = hp.Int('units1', 64, 256, step=32)
    units2 = hp.Int('units2', 32, 128, step=32)
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(18,)),
        tf.keras.layers.Dense(units1, activation='relu'),
        tf.keras.layers.Dense(units2, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

def build_knn_regressor(hp):
    units1 = hp.Int('units1', 64, 256, step=32)
    units2 = hp.Int('units2', 32, 128, step=32)
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(18,)),
        tf.keras.layers.Dense(units1, activation='relu'),
        tf.keras.layers.Dense(units2, activation='relu'),
        tf.keras.layers.Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
                  loss='mean_squared_error')
    return model

# Hyperparameter tuning function with cross-validation
def cross_val_hyperparameter_tuning(X, y, model_builder, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    fold_metrics = []
    
    # Clear the tuner directory before each run
    tuner_dir = 'tuner_dir'
    if os.path.exists(tuner_dir):
        shutil.rmtree(tuner_dir)

    for train_index, val_index in kf.split(X):
        X_train, X_val = X[train_index], X[val_index]
        y_train, y_val = y[train_index], y[val_index]
        
        tuner = kt.RandomSearch(
            model_builder,
            objective='val_loss',
            max_trials=10,
            executions_per_trial=1,
            directory='tuner_dir',
            project_name='tuning'
        )

        tuner.search(X_train, y_train, epochs=50, validation_data=(X_val, y_val))
        best_models = tuner.get_best_models(num_models=1)
        
        if best_models:
            best_model = best_models[0]
            val_loss = best_model.evaluate(X_val, y_val, verbose=0)
            fold_metrics.append(val_loss)
        else:
            print("No valid model found for this fold.")
    
    if fold_metrics:
        avg_metric = np.mean(fold_metrics)
        return best_model, avg_metric
    else:
        raise RuntimeError("All folds failed to produce a valid model.")

# Function to create combined dataset with given ratio for each floor
def create_combined_dataset(actual_data, synthetic_data, ratio):
    combined_data = pd.DataFrame()
    floors = actual_data['z'].unique()
    for floor in floors:
        actual_floor_data = actual_data[actual_data['z'] == floor]
        synthetic_floor_data = synthetic_data[synthetic_data['z'] == floor]
        
        n_actual = int(len(actual_floor_data) * ratio)
        n_synthetic = len(actual_floor_data) - n_actual
        
        actual_sample = actual_floor_data.sample(n_actual, random_state=42)
        if len(synthetic_floor_data) < n_synthetic:
            synthetic_sample = synthetic_floor_data.sample(n_synthetic, replace=True, random_state=42)
        else:
            synthetic_sample = synthetic_floor_data.sample(n_synthetic, random_state=42)
        
        combined_floor_data = pd.concat([actual_sample, synthetic_sample])
        combined_data = pd.concat([combined_data, combined_floor_data], ignore_index=True)
        
    return combined_data

# Function to train and convert model to TensorFlow Lite
def train_and_convert_to_tflite(X, y, model_builder, model_name, dataset_name, ratio):
    best_model, avg_metric = cross_val_hyperparameter_tuning(X, y, model_builder)
    
    # Convert to TensorFlow Lite
    converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
    tflite_model = converter.convert()

    # Save the model
    model_path = f'TFLite_NEW_senior_saved_model/{dataset_name}_{ratio}_{model_name}.tflite'
    with open(model_path, 'wb') as f:
        f.write(tflite_model)
    
    return model_path, avg_metric

# Function to calculate Mean Distance Error
def mean_distance_error(y_true, y_pred):
    return np.mean(np.sqrt(np.sum((y_true - y_pred) ** 2, axis=1)))

# Train and evaluate models with cross-validation and hyperparameter tuning
ratios = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]
datasets = {
    'actual_ml': synthetic_data_ml,
    'actual_gan': synthetic_data_gan,
    'actual_ml_gan': synthetic_data_combined
}

model_builders = {
    'LogisticRegression': build_logistic_regression,
    'DecisionTreeClassifier': build_decision_tree_classifier,
    'DecisionTreeRegressor': build_decision_tree_regressor,
    'RandomForestClassifier': build_random_forest_classifier,
    'RandomForestRegressor': build_random_forest_regressor,
    'GradientBoostingClassifier': build_gradient_boosting_classifier,
    'GradientBoostingRegressor': build_gradient_boosting_regressor,
    'KNeighborsClassifier': build_knn_classifier,
    'KNeighborsRegressor': build_knn_regressor
}

for dataset_name, synthetic_data in datasets.items():
    for ratio in ratios:
        combined_data = create_combined_dataset(actual_data, synthetic_data, ratio)
        
        # Convert DataFrame to numpy array
        X = combined_data[[f'RSSI{i+1}' for i in range(18)]].values
        y_floor = combined_data['z'].values
        y_coord = combined_data[['x', 'y']].values
        
        # Floor classification training and evaluation
        for model_name in ['LogisticRegression', 'DecisionTreeClassifier', 'RandomForestClassifier', 'GradientBoostingClassifier', 'KNeighborsClassifier']:
            model_path, avg_metric = train_and_convert_to_tflite(X, y_floor, model_builders[model_name], model_name, f'{dataset_name}_{ratio}_floor', ratio)
            print(f'Model saved to {model_path}, Average Validation Loss: {avg_metric}')
        
        # Coordinate regression training and evaluation
        for model_name in ['DecisionTreeRegressor', 'RandomForestRegressor', 'GradientBoostingRegressor', 'KNeighborsRegressor']:
            model_path, avg_metric = train_and_convert_to_tflite(X, y_coord, model_builders[model_name], model_name, f'{dataset_name}_{ratio}_coord', ratio)
            print(f'Model saved to {model_path}, Average Validation Loss: {avg_metric}')
# Out:
# Trial 10 Complete [00h 00m 19s]
# val_loss: 85.00841522216797
#
# Best val_loss So Far: 84.27782440185547
# Total elapsed time: 00h 03m 09s
# c:\Users\prabw\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Reloading Tuner from tuner_dir\tuning\tuner0.json
# Reloading Tuner from tuner_dir\tuning\tuner0.json
# Reloading Tuner from tuner_dir\tuning\tuner0.json
# Reloading Tuner from tuner_dir\tuning\tuner0.json
# INFO:tensorflow:Assets written to: C:\Users\prabw\AppData\Local\Temp\tmpa5e7btwn\assets
# INFO:tensorflow:Assets written to: C:\Users\prabw\AppData\Local\Temp\tmpa5e7btwn\assets
# Saved artifact at 'C:\Users\prabw\AppData\Local\Temp\tmpa5e7btwn'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 18), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2867363840080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2867406595344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2867406589776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2867406598416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2867406598608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2867406595728: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model saved to TFLite_NEW_senior_saved_model/actual_ml_gan_0.1_coord_0.1_KNeighborsRegressor.tflite, Average Validation Loss: 81.79132843017578

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os

# Function to calculate Mean Distance Error
def mean_distance_error(y_true, y_pred):
    return np.mean(np.sqrt(np.sum((y_true - y_pred) ** 2, axis=1)))

# Function to load a TensorFlow Lite model and make predictions
def load_and_predict_with_tflite_model(model_path, X_test):
    # Load the TensorFlow Lite model
    interpreter = tf.lite.Interpreter(model_path=model_path)
    interpreter.allocate_tensors()

    # Get input and output details
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    # Prepare the input data in the format expected by the model
    X_test = np.array(X_test, dtype=np.float32)

    # Predict using the TensorFlow Lite model
    predictions = []
    for i in range(len(X_test)):
        interpreter.set_tensor(input_details[0]['index'], [X_test[i]])
        interpreter.invoke()
        output_data = interpreter.get_tensor(output_details[0]['index'])
        predictions.append(output_data[0])

    return np.array(predictions)

# Load the actual dataset for testing
actual_test_data = pd.read_csv('original_CMKL1.csv')

# Prepare the data for testing
X_test = actual_test_data[[f'RSSI{i+1}' for i in range(18)]]
y_test_coord = actual_test_data[['x', 'y']]

# Define the directory where models are saved
model_directory = 'TFLite_NEW_senior_saved_model'

# Iterate over the models and calculate Mean Distance Error
for ratio in [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]:
    for dataset_name in ['actual_ml', 'actual_gan', 'actual_ml_gan']:
        for model_name in ['DecisionTreeRegressor', 'RandomForestRegressor', 'GradientBoostingRegressor', 'KNeighborsRegressor']:
            model_path = f'{model_directory}/{dataset_name}_{ratio}_coord_{ratio}_{model_name}.tflite'
            print(f'Testing model: {model_path}')
            
            # Predict using the TensorFlow Lite model
            predictions = load_and_predict_with_tflite_model(model_path, X_test)
            
            # Calculate Mean Distance Error
            mde = mean_distance_error(y_test_coord.values, predictions)
            print(f'Mean Distance Error for {dataset_name} at ratio {ratio} with model {model_name}: {mde} meters')
# Out:
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.9_coord_0.9_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.9 with model DecisionTreeRegressor: 11.800111200029365 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.9_coord_0.9_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.9 with model RandomForestRegressor: 11.565227162020669 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.9_coord_0.9_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.9 with model GradientBoostingRegressor: 11.56880737640622 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.9_coord_0.9_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.9 with model KNeighborsRegressor: 11.577313107221768 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.9_coord_0.9_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.9 with model DecisionTreeRegressor: 11.749010847252794 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.9_coord_0.9_RandomForestRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.9 with model RandomForestRegressor: 11.6015484417427 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.9_coord_0.9_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.9 with model GradientBoostingRegressor: 11.556424564695886 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.9_coord_0.9_KNeighborsRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.9 with model KNeighborsRegressor: 11.591415091141466 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.9_coord_0.9_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.9 with model DecisionTreeRegressor: 11.787364918001462 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.9_coord_0.9_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.9 with model RandomForestRegressor: 11.57111757971102 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.9_coord_0.9_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.9 with model GradientBoostingRegressor: 11.57668461700691 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.9_coord_0.9_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.9 with model KNeighborsRegressor: 11.555982782166033 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.8_coord_0.8_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.8 with model DecisionTreeRegressor: 11.788772823884798 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.8_coord_0.8_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.8 with model RandomForestRegressor: 11.611706005480325 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.8_coord_0.8_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.8 with model GradientBoostingRegressor: 11.574818273607477 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.8_coord_0.8_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.8 with model KNeighborsRegressor: 11.574648269366085 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.8_coord_0.8_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.8 with model DecisionTreeRegressor: 11.815658035773946 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.8_coord_0.8_RandomForestRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.8 with model RandomForestRegressor: 11.620421090242909 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.8_coord_0.8_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.8 with model GradientBoostingRegressor: 11.647764519079251 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.8_coord_0.8_KNeighborsRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.8 with model KNeighborsRegressor: 11.61330889965582 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.8_coord_0.8_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.8 with model DecisionTreeRegressor: 11.761731398704638 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.8_coord_0.8_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.8 with model RandomForestRegressor: 11.56647543632344 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.8_coord_0.8_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.8 with model GradientBoostingRegressor: 11.577031102605567 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.8_coord_0.8_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.8 with model KNeighborsRegressor: 11.630311148938663 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.7_coord_0.7_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.7 with model DecisionTreeRegressor: 11.864043142305766 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.7_coord_0.7_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.7 with model RandomForestRegressor: 11.586264905260675 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.7_coord_0.7_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.7 with model GradientBoostingRegressor: 11.600776694346209 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.7_coord_0.7_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.7 with model KNeighborsRegressor: 11.575352691474418 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.7_coord_0.7_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.7 with model DecisionTreeRegressor: 11.819593024567475 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.7_coord_0.7_RandomForestRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.7 with model RandomForestRegressor: 11.63217409580771 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.7_coord_0.7_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.7 with model GradientBoostingRegressor: 11.620249645188526 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.7_coord_0.7_KNeighborsRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.7 with model KNeighborsRegressor: 11.658147586604956 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.7_coord_0.7_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.7 with model DecisionTreeRegressor: 11.79150528127119 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.7_coord_0.7_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.7 with model RandomForestRegressor: 11.554656008472021 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.7_coord_0.7_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.7 with model GradientBoostingRegressor: 11.574361516524302 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.7_coord_0.7_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.7 with model KNeighborsRegressor: 11.62239632781082 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.6_coord_0.6_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.6 with model DecisionTreeRegressor: 11.825517182755256 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.6_coord_0.6_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.6 with model RandomForestRegressor: 11.64763038028564 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.6_coord_0.6_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.6 with model GradientBoostingRegressor: 11.560061790389415 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.6_coord_0.6_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.6 with model KNeighborsRegressor: 11.672760765284828 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.6_coord_0.6_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.6 with model DecisionTreeRegressor: 11.774635232950747 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.6_coord_0.6_RandomForestRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.6 with model RandomForestRegressor: 11.664631758317231 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.6_coord_0.6_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.6 with model GradientBoostingRegressor: 11.7304114649582 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.6_coord_0.6_KNeighborsRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.6 with model KNeighborsRegressor: 11.65128667427952 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.6_coord_0.6_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.6 with model DecisionTreeRegressor: 11.780175390739661 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.6_coord_0.6_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.6 with model RandomForestRegressor: 11.647337841806703 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.6_coord_0.6_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.6 with model GradientBoostingRegressor: 11.642079888842513 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.6_coord_0.6_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.6 with model KNeighborsRegressor: 11.625565994468115 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.5_coord_0.5_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.5 with model DecisionTreeRegressor: 11.82523493554789 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.5_coord_0.5_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.5 with model RandomForestRegressor: 11.696035909192792 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.5_coord_0.5_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.5 with model GradientBoostingRegressor: 11.62734125566639 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.5_coord_0.5_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.5 with model KNeighborsRegressor: 11.666762714315045 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.5_coord_0.5_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.5 with model DecisionTreeRegressor: 11.79026780283151 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.5_coord_0.5_RandomForestRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.5 with model RandomForestRegressor: 11.654629230810285 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.5_coord_0.5_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.5 with model GradientBoostingRegressor: 11.669385857977876 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.5_coord_0.5_KNeighborsRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.5 with model KNeighborsRegressor: 11.6210030833787 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.5_coord_0.5_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.5 with model DecisionTreeRegressor: 11.867641208170365 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.5_coord_0.5_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.5 with model RandomForestRegressor: 11.588445743138434 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.5_coord_0.5_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.5 with model GradientBoostingRegressor: 11.58649159995843 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.5_coord_0.5_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.5 with model KNeighborsRegressor: 11.624574947538092 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.4_coord_0.4_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.4 with model DecisionTreeRegressor: 11.857186303059343 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.4_coord_0.4_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.4 with model RandomForestRegressor: 11.62112122186118 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.4_coord_0.4_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.4 with model GradientBoostingRegressor: 11.637304251936365 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.4_coord_0.4_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.4 with model KNeighborsRegressor: 11.640500520605935 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.4_coord_0.4_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.4 with model DecisionTreeRegressor: 11.924833487467986 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.4_coord_0.4_RandomForestRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.4 with model RandomForestRegressor: 11.627601133240793 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.4_coord_0.4_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.4 with model GradientBoostingRegressor: 11.61183868909578 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.4_coord_0.4_KNeighborsRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.4 with model KNeighborsRegressor: 11.672984334597826 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.4_coord_0.4_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.4 with model DecisionTreeRegressor: 11.934754086322988 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.4_coord_0.4_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.4 with model RandomForestRegressor: 11.737891893706388 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.4_coord_0.4_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.4 with model GradientBoostingRegressor: 11.696278079544431 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.4_coord_0.4_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.4 with model KNeighborsRegressor: 11.613467989854286 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.3_coord_0.3_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.3 with model DecisionTreeRegressor: 11.92823099257526 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.3_coord_0.3_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.3 with model RandomForestRegressor: 11.649896804978184 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.3_coord_0.3_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.3 with model GradientBoostingRegressor: 11.639065841940866 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.3_coord_0.3_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.3 with model KNeighborsRegressor: 11.667397930540712 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.3_coord_0.3_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.3 with model DecisionTreeRegressor: 11.86594411947475 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.3_coord_0.3_RandomForestRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.3 with model RandomForestRegressor: 11.63477528981466 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.3_coord_0.3_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.3 with model GradientBoostingRegressor: 11.679044678795009 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.3_coord_0.3_KNeighborsRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.3 with model KNeighborsRegressor: 11.696743399695501 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.3_coord_0.3_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.3 with model DecisionTreeRegressor: 11.906558277937274 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.3_coord_0.3_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.3 with model RandomForestRegressor: 11.71788508328259 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.3_coord_0.3_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.3 with model GradientBoostingRegressor: 11.71755791905713 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.3_coord_0.3_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.3 with model KNeighborsRegressor: 11.672978944055657 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.2_coord_0.2_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.2 with model DecisionTreeRegressor: 11.996564034169308 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.2_coord_0.2_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.2 with model RandomForestRegressor: 11.712835651624868 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.2_coord_0.2_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.2 with model GradientBoostingRegressor: 11.742834886637969 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.2_coord_0.2_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.2 with model KNeighborsRegressor: 11.84141221648777 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.2_coord_0.2_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.2 with model DecisionTreeRegressor: 11.894222838457587 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.2_coord_0.2_RandomForestRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.2 with model RandomForestRegressor: 11.682182972181604 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.2_coord_0.2_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.2 with model GradientBoostingRegressor: 11.749400135013964 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.2_coord_0.2_KNeighborsRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.2 with model KNeighborsRegressor: 11.698153404055505 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.2_coord_0.2_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.2 with model DecisionTreeRegressor: 11.996306958478232 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.2_coord_0.2_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.2 with model RandomForestRegressor: 11.730290488512997 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.2_coord_0.2_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.2 with model GradientBoostingRegressor: 11.743192616861077 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.2_coord_0.2_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.2 with model KNeighborsRegressor: 11.727260380144505 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.1_coord_0.1_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.1 with model DecisionTreeRegressor: 12.058503138652618 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.1_coord_0.1_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.1 with model RandomForestRegressor: 11.78618618989949 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.1_coord_0.1_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.1 with model GradientBoostingRegressor: 11.776127710790599 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_0.1_coord_0.1_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml at ratio 0.1 with model KNeighborsRegressor: 11.8138434731833 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.1_coord_0.1_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.1 with model DecisionTreeRegressor: 11.995667544253328 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.1_coord_0.1_RandomForestRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.1 with model RandomForestRegressor: 11.815291994801324 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.1_coord_0.1_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.1 with model GradientBoostingRegressor: 11.812049127798531 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_gan_0.1_coord_0.1_KNeighborsRegressor.tflite
# Mean Distance Error for actual_gan at ratio 0.1 with model KNeighborsRegressor: 11.777160354092246 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.1_coord_0.1_DecisionTreeRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.1 with model DecisionTreeRegressor: 12.045308517185475 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.1_coord_0.1_RandomForestRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.1 with model RandomForestRegressor: 11.829220245605635 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.1_coord_0.1_GradientBoostingRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.1 with model GradientBoostingRegressor: 11.857367822647014 meters
# Testing model: TFLite_NEW_senior_saved_model/actual_ml_gan_0.1_coord_0.1_KNeighborsRegressor.tflite
# Mean Distance Error for actual_ml_gan at ratio 0.1 with model KNeighborsRegressor: 11.830278672747983 meters
